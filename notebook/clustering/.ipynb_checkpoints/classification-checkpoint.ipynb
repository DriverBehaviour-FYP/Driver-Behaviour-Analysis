# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn import metrics

# %%
dataset = pd.read_csv("norms_clustering_3_clusters_segments_1000M.csv")

# %%
dataset.columns
# Out:
# Index(['index', 'segment_id', 'road_section_id', 'segment_starting_time',
#        'segment_ending_time', 'trip_id', 'deviceid', 'date', 'start_terminal',
#        'end_terminal', 'direction', 'day_of_week', 'hour_of_day', 'speed_mean',
#        'speed_max', 'speed_std', 'elevation_p', 'elevation_n', 'ele_X_speed_p',
#        'ele_X_speed_n', 'max_elevation_p', 'max_elevation_n',
#        'max_ele_X_speed_p', 'max_ele_X_speed_n', 'eleXspeed_count_p',
#        'eleXspeed_count_n', 'average_acceleration', 'average_deacceleration',
#        'std_acc_dacc', 'max_acceleration', 'max_deacceleration',
#        'no_data_points', 'no_acc_points', 'no_deacc_points', 'stop_count',
#        'cluster'],
#       dtype='object')

# %%
dataset.drop(columns=['index', 'segment_starting_time', 'segment_ending_time', 'trip_id', 'date', 'end_terminal', 'start_terminal', 'average_acceleration', 'average_deacceleration', 'std_acc_dacc', 'max_acceleration', 'max_deacceleration', 'no_data_points', 'no_acc_points', 'no_deacc_points'], inplace=True)

# %%
dataset.columns
# Out:
# Index(['segment_id', 'road_section_id', 'deviceid', 'direction', 'day_of_week',
#        'hour_of_day', 'speed_mean', 'speed_max', 'speed_std', 'elevation_p',
#        'elevation_n', 'ele_X_speed_p', 'ele_X_speed_n', 'max_elevation_p',
#        'max_elevation_n', 'max_ele_X_speed_p', 'max_ele_X_speed_n',
#        'eleXspeed_count_p', 'eleXspeed_count_n', 'stop_count', 'cluster'],
#       dtype='object')

# %%
dataset.drop(columns=['speed_mean', 'speed_max', 'speed_std', 'elevation_p',
       'elevation_n', 'ele_X_speed_p', 'ele_X_speed_n', 'max_elevation_p',
       'max_elevation_n', 'max_ele_X_speed_p', 'max_ele_X_speed_n',
       'eleXspeed_count_p', 'eleXspeed_count_n', 'stop_count',], inplace=True)

# %%
dataset
# Out:
#         segment_id  road_section_id  deviceid  direction  day_of_week  \
# 0                1              -17       116          2            5
# 1                2              -16       116          2            5
# 2                3              -15       116          2            5
# 3                4              -14       116          2            5
# 4                5              -13       116          2            5
# ...            ...              ...       ...        ...          ...
# 281191      287398               -5      1377          2            1
# 281192      287399               -4      1377          2            1
# 281193      287400               -3      1377          2            1
# 281194      287401               -2      1377          2            1
# 281195      287402               -1      1377          2            1
#
#         hour_of_day  cluster
# 0                 7        2
# 1                 7        0
# 2                 7        0
# 3                 7        0
# 4                 7        1
# ...             ...      ...
# 281191           17        1
# 281192           17        1
# 281193           17        0
# 281194           17        1
# 281195           17        0
#
# [281196 rows x 7 columns]

# %%
train = dataset.drop(columns=['segment_id'])

# %%
train
# Out:
#         road_section_id  deviceid  direction  day_of_week  hour_of_day  \
# 0                   -17       116          2            5            7
# 1                   -16       116          2            5            7
# 2                   -15       116          2            5            7
# 3                   -14       116          2            5            7
# 4                   -13       116          2            5            7
# ...                 ...       ...        ...          ...          ...
# 281191               -5      1377          2            1           17
# 281192               -4      1377          2            1           17
# 281193               -3      1377          2            1           17
# 281194               -2      1377          2            1           17
# 281195               -1      1377          2            1           17
#
#         cluster
# 0             2
# 1             0
# 2             0
# 3             0
# 4             1
# ...         ...
# 281191        1
# 281192        1
# 281193        0
# 281194        1
# 281195        0
#
# [281196 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( train.drop(columns=['cluster']), train['cluster'], test_size=0.33, random_state=42)

# %%
rf_params = {"bootstrap": [False, True],
             "n_estimators": [60, 70, 80, 90, 100],
             "max_features": [0.6, 0.65, 0.7, 0.75, 0.8],
             "min_samples_leaf": [8, 10, 12, 14],
             "min_samples_split": [3, 5, 7]
        }

rf_search = RandomizedSearchCV(estimator=RandomForestClassifier(), param_distributions=rf_params, scoring="accuracy", n_iter=100)
rf_search.fit(X_train, y_train)
best_rf = rf_search.best_estimator_

# %%
rf =best_rf

# %%
best_rf
# Out:
# RandomForestClassifier(max_features=0.65, min_samples_leaf=14,
#                        min_samples_split=3, n_estimators=80)

# %%
RandomForestClassifier(max_features=0.65, min_samples_leaf=14,
                       min_samples_split=3, n_estimators=80)

# %%
rf_prediction = best_rf.predict(X_test)
metrics.accuracy_score(y_test, rf_prediction)
# Out:
# 0.5757098981626165

# %%
rf = RandomForestClassifier(max_features=0.65, min_samples_leaf=14,min_samples_split=3, n_estimators=1000)
rf.fit(X_train, y_train)
rf_prediction = rf.predict(X_test)
metrics.accuracy_score(y_test, rf_prediction)
# Out:
# 0.5763672611670887

# %%
import xgboost as xgb
# Instantiate an XGBoost classifier object
clf = xgb.XGBClassifier(objective='binary:logistic', n_estimators=100, seed=42)

# Train the classifier
clf.fit(X_train, y_train)
# Predictions
y_pred = clf.predict(X_test)

# Calculate the accuracy
accuracy = metrics.accuracy_score(y_test, y_pred)
print(metrics.classification_report(y_test, y_pred))
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.34      0.44     20988
#            1       0.60      0.77      0.67     45390
#            2       0.52      0.45      0.48     26417
#
#     accuracy                           0.58     92795
#    macro avg       0.58      0.52      0.53     92795
# weighted avg       0.58      0.58      0.57     92795
#
# Accuracy: 58.10%

# %%
clf.feature_importances_
# Out:
# array([0.13420066, 0.67424333, 0.        , 0.04570119, 0.1458548 ],
#       dtype=float32)

# %%
params = {
    'max_depth': [3, 4, 5, 6, 7, 8],
    'min_child_weight': [1, 2, 3, 4],
    'gamma': [0, 0.1, 0.2, 0.3, 0.4],
    'colsample_bytree': [0.3, 0.4, 0.5, 0.6, 0.7],
    'subsample': [0.6, 0.7, 0.8, 0.9],
    'learning_rate': [0.01, 0.02, 0.05, 0.1],
    'n_estimators': [100, 150, 200, 250]
}
xgb_clf = xgb.XGBClassifier(objective='binary:logistic', seed=42)

# Setup the Randomized Search with cross-validation
random_search = RandomizedSearchCV(xgb_clf, param_distributions=params, n_iter=100, cv=3, verbose=2, random_state=42, scoring='accuracy')

# Fit Randomized Search
random_search.fit(X_train, y_train)
best_clf = random_search.best_estimator_
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.02, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.9; total time=   2.6s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.02, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.9; total time=   2.3s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.02, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.9; total time=   2.3s
# [CV] END colsample_bytree=0.3, gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=2, n_estimators=250, subsample=0.6; total time=   6.3s
# [CV] END colsample_bytree=0.3, gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=2, n_estimators=250, subsample=0.6; total time=   8.1s
# [CV] END colsample_bytree=0.3, gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=2, n_estimators=250, subsample=0.6; total time=   8.1s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=250, subsample=0.8; total time=   9.0s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=250, subsample=0.8; total time=   8.6s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=250, subsample=0.8; total time=   8.3s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.02, max_depth=5, min_child_weight=2, n_estimators=150, subsample=0.6; total time=   5.0s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.02, max_depth=5, min_child_weight=2, n_estimators=150, subsample=0.6; total time=   5.4s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.02, max_depth=5, min_child_weight=2, n_estimators=150, subsample=0.6; total time=   5.0s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.7; total time=   6.1s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.7; total time=   6.0s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.01, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.7; total time=   6.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.1, max_depth=8, min_child_weight=2, n_estimators=100, subsample=0.8; total time=   4.1s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.1, max_depth=8, min_child_weight=2, n_estimators=100, subsample=0.8; total time=   4.0s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.1, max_depth=8, min_child_weight=2, n_estimators=100, subsample=0.8; total time=   3.9s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=8, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   8.9s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=8, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   8.6s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=8, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   8.5s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.02, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   6.4s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.02, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   6.2s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.02, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   6.4s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.02, max_depth=7, min_child_weight=2, n_estimators=150, subsample=0.9; total time=   5.8s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.02, max_depth=7, min_child_weight=2, n_estimators=150, subsample=0.9; total time=   5.8s
# [CV] END colsample_bytree=0.5, gamma=0, learning_rate=0.02, max_depth=7, min_child_weight=2, n_estimators=150, subsample=0.9; total time=   5.8s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=2, n_estimators=150, subsample=0.7; total time=   4.7s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=2, n_estimators=150, subsample=0.7; total time=   4.6s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=2, n_estimators=150, subsample=0.7; total time=   4.6s
# [CV] END colsample_bytree=0.3, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   2.9s
# [CV] END colsample_bytree=0.3, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   3.0s
# [CV] END colsample_bytree=0.3, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   2.9s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   3.1s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   3.2s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   3.3s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.02, max_depth=7, min_child_weight=4, n_estimators=250, subsample=0.9; total time=   8.1s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.02, max_depth=7, min_child_weight=4, n_estimators=250, subsample=0.9; total time=   8.1s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.02, max_depth=7, min_child_weight=4, n_estimators=250, subsample=0.9; total time=   8.0s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.05, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.9; total time=   7.1s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.05, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.9; total time=   6.8s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.05, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.9; total time=   6.7s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.02, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   3.9s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.02, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   3.8s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.02, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   3.7s
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.7; total time=   6.8s
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.7; total time=   6.8s
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.7; total time=   6.8s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.05, max_depth=7, min_child_weight=2, n_estimators=150, subsample=0.7; total time=   6.0s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.05, max_depth=7, min_child_weight=2, n_estimators=150, subsample=0.7; total time=   6.0s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.05, max_depth=7, min_child_weight=2, n_estimators=150, subsample=0.7; total time=   6.0s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.01, max_depth=6, min_child_weight=4, n_estimators=250, subsample=0.6; total time=   8.1s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.01, max_depth=6, min_child_weight=4, n_estimators=250, subsample=0.6; total time=   8.0s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.01, max_depth=6, min_child_weight=4, n_estimators=250, subsample=0.6; total time=   8.2s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.6; total time=   7.7s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.6; total time=   8.1s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=200, subsample=0.6; total time=   7.8s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=4, n_estimators=200, subsample=0.8; total time=   8.5s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=4, n_estimators=200, subsample=0.8; total time=   8.4s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=4, n_estimators=200, subsample=0.8; total time=   8.3s
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.02, max_depth=4, min_child_weight=4, n_estimators=250, subsample=0.8; total time=   8.3s
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.02, max_depth=4, min_child_weight=4, n_estimators=250, subsample=0.8; total time=   8.5s
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.02, max_depth=4, min_child_weight=4, n_estimators=250, subsample=0.8; total time=   8.8s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.1, max_depth=8, min_child_weight=4, n_estimators=250, subsample=0.9; total time=   9.6s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.1, max_depth=8, min_child_weight=4, n_estimators=250, subsample=0.9; total time=   9.3s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.1, max_depth=8, min_child_weight=4, n_estimators=250, subsample=0.9; total time=   9.4s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=200, subsample=0.9; total time=   5.7s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=200, subsample=0.9; total time=   5.9s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=200, subsample=0.9; total time=   5.8s
# [CV] END colsample_bytree=0.3, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=4, n_estimators=250, subsample=0.7; total time=   8.3s
# [CV] END colsample_bytree=0.3, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=4, n_estimators=250, subsample=0.7; total time=   8.1s
# [CV] END colsample_bytree=0.3, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=4, n_estimators=250, subsample=0.7; total time=   8.6s
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.02, max_depth=7, min_child_weight=3, n_estimators=250, subsample=0.8; total time=   9.7s
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.02, max_depth=7, min_child_weight=3, n_estimators=250, subsample=0.8; total time=  13.7s
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.02, max_depth=7, min_child_weight=3, n_estimators=250, subsample=0.8; total time=  13.1s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.02, max_depth=3, min_child_weight=4, n_estimators=250, subsample=0.7; total time=  10.5s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.02, max_depth=3, min_child_weight=4, n_estimators=250, subsample=0.7; total time=   9.5s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.02, max_depth=3, min_child_weight=4, n_estimators=250, subsample=0.7; total time=   9.1s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   7.9s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   8.1s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   8.4s
# [CV] END colsample_bytree=0.3, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.9; total time=   3.4s
# [CV] END colsample_bytree=0.3, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.9; total time=   3.6s
# [CV] END colsample_bytree=0.3, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.9; total time=   4.2s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=4, n_estimators=250, subsample=0.9; total time=   9.2s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=4, n_estimators=250, subsample=0.9; total time=   8.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=4, n_estimators=250, subsample=0.9; total time=   8.6s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.02, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   4.7s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.02, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   4.5s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.02, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   4.4s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.02, max_depth=4, min_child_weight=3, n_estimators=150, subsample=0.6; total time=   5.0s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.02, max_depth=4, min_child_weight=3, n_estimators=150, subsample=0.6; total time=   6.2s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.02, max_depth=4, min_child_weight=3, n_estimators=150, subsample=0.6; total time=   6.2s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.05, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.8; total time=   4.3s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.05, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.8; total time=   3.6s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.05, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.8; total time=   3.6s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=2, n_estimators=150, subsample=0.6; total time=   5.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=2, n_estimators=150, subsample=0.6; total time=   6.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=2, n_estimators=150, subsample=0.6; total time=   5.1s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.02, max_depth=7, min_child_weight=3, n_estimators=150, subsample=0.8; total time=   7.2s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.02, max_depth=7, min_child_weight=3, n_estimators=150, subsample=0.8; total time=   6.2s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.02, max_depth=7, min_child_weight=3, n_estimators=150, subsample=0.8; total time=   6.1s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.01, max_depth=7, min_child_weight=2, n_estimators=100, subsample=0.7; total time=   4.3s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.01, max_depth=7, min_child_weight=2, n_estimators=100, subsample=0.7; total time=   4.3s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.01, max_depth=7, min_child_weight=2, n_estimators=100, subsample=0.7; total time=   4.1s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.9; total time=   4.2s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.9; total time=   5.0s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.9; total time=   5.1s
# [CV] END colsample_bytree=0.4, gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.6; total time=   9.5s
# [CV] END colsample_bytree=0.4, gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.6; total time=   8.9s
# [CV] END colsample_bytree=0.4, gamma=0, learning_rate=0.05, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.6; total time=  11.1s
# [CV] END colsample_bytree=0.4, gamma=0, learning_rate=0.02, max_depth=8, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   5.6s
# [CV] END colsample_bytree=0.4, gamma=0, learning_rate=0.02, max_depth=8, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   4.5s
# [CV] END colsample_bytree=0.4, gamma=0, learning_rate=0.02, max_depth=8, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   4.5s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   9.7s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   9.1s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   8.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.7; total time=   7.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.7; total time=   7.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.7; total time=   7.4s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=4, n_estimators=150, subsample=0.6; total time=   6.0s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=4, n_estimators=150, subsample=0.6; total time=   5.7s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=4, n_estimators=150, subsample=0.6; total time=   5.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.02, max_depth=3, min_child_weight=4, n_estimators=200, subsample=0.9; total time=   6.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.02, max_depth=3, min_child_weight=4, n_estimators=200, subsample=0.9; total time=   6.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.02, max_depth=3, min_child_weight=4, n_estimators=200, subsample=0.9; total time=   6.4s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=150, subsample=0.9; total time=   6.1s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=150, subsample=0.9; total time=   6.1s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=150, subsample=0.9; total time=   5.9s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.02, max_depth=8, min_child_weight=1, n_estimators=250, subsample=0.7; total time=  10.5s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.02, max_depth=8, min_child_weight=1, n_estimators=250, subsample=0.7; total time=  11.3s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.02, max_depth=8, min_child_weight=1, n_estimators=250, subsample=0.7; total time=  10.6s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.02, max_depth=6, min_child_weight=2, n_estimators=100, subsample=0.6; total time=   4.0s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.02, max_depth=6, min_child_weight=2, n_estimators=100, subsample=0.6; total time=   4.4s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.02, max_depth=6, min_child_weight=2, n_estimators=100, subsample=0.6; total time=   4.2s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.02, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   3.2s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.02, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   3.2s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.02, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   3.4s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   3.1s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   3.4s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.7; total time=   3.2s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.05, max_depth=4, min_child_weight=3, n_estimators=150, subsample=0.9; total time=   5.1s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.05, max_depth=4, min_child_weight=3, n_estimators=150, subsample=0.9; total time=   5.0s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.05, max_depth=4, min_child_weight=3, n_estimators=150, subsample=0.9; total time=   5.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.9; total time=   3.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.9; total time=   3.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.9; total time=   3.4s
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   3.8s
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   4.2s
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   3.9s
# [CV] END colsample_bytree=0.3, gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=250, subsample=0.7; total time=   9.0s
# [CV] END colsample_bytree=0.3, gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=250, subsample=0.7; total time=   9.3s
# [CV] END colsample_bytree=0.3, gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=250, subsample=0.7; total time=   9.8s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=150, subsample=0.7; total time=   7.0s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=150, subsample=0.7; total time=   5.8s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=150, subsample=0.7; total time=   5.8s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.7; total time=  10.5s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.7; total time=  11.4s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.7; total time=  10.3s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.02, max_depth=4, min_child_weight=2, n_estimators=250, subsample=0.6; total time=   8.6s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.02, max_depth=4, min_child_weight=2, n_estimators=250, subsample=0.6; total time=   8.5s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.02, max_depth=4, min_child_weight=2, n_estimators=250, subsample=0.6; total time=  11.4s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.02, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.7; total time=   9.5s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.02, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.7; total time=   7.3s
# [CV] END colsample_bytree=0.3, gamma=0.4, learning_rate=0.02, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.7; total time=   7.3s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   7.0s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   7.1s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   6.9s
# [CV] END colsample_bytree=0.3, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.7; total time=   3.4s
# [CV] END colsample_bytree=0.3, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.7; total time=   3.9s
# [CV] END colsample_bytree=0.3, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.7; total time=   3.7s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=200, subsample=0.7; total time=   8.8s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=200, subsample=0.7; total time=   8.7s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=200, subsample=0.7; total time=   8.2s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.02, max_depth=3, min_child_weight=4, n_estimators=250, subsample=0.7; total time=   8.5s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.02, max_depth=3, min_child_weight=4, n_estimators=250, subsample=0.7; total time=   8.7s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.02, max_depth=3, min_child_weight=4, n_estimators=250, subsample=0.7; total time=   8.7s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=8, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   5.6s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=8, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   5.8s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=8, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   5.0s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=8, min_child_weight=2, n_estimators=250, subsample=0.8; total time=  12.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=8, min_child_weight=2, n_estimators=250, subsample=0.8; total time=  13.6s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=8, min_child_weight=2, n_estimators=250, subsample=0.8; total time=  11.6s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=250, subsample=0.8; total time=   8.1s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=250, subsample=0.8; total time=   8.6s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=250, subsample=0.8; total time=   8.2s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=150, subsample=0.9; total time=   6.0s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=150, subsample=0.9; total time=   6.1s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=150, subsample=0.9; total time=   5.9s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.9; total time=   6.4s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.9; total time=   6.6s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.9; total time=   7.3s
# [CV] END colsample_bytree=0.3, gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   7.5s
# [CV] END colsample_bytree=0.3, gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   7.2s
# [CV] END colsample_bytree=0.3, gamma=0, learning_rate=0.05, max_depth=6, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   6.8s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=250, subsample=0.7; total time=   7.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=250, subsample=0.7; total time=   7.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=250, subsample=0.7; total time=   7.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=150, subsample=0.6; total time=   5.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=150, subsample=0.6; total time=   4.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=150, subsample=0.6; total time=   4.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=250, subsample=0.9; total time=   9.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=250, subsample=0.9; total time=   9.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=6, min_child_weight=1, n_estimators=250, subsample=0.9; total time=   9.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=3, n_estimators=250, subsample=0.6; total time=   8.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=3, n_estimators=250, subsample=0.6; total time=   8.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=3, n_estimators=250, subsample=0.6; total time=   9.3s
# [CV] END colsample_bytree=0.4, gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=2, n_estimators=100, subsample=0.7; total time=   3.6s
# [CV] END colsample_bytree=0.4, gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=2, n_estimators=100, subsample=0.7; total time=   3.3s
# [CV] END colsample_bytree=0.4, gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=2, n_estimators=100, subsample=0.7; total time=   3.3s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=250, subsample=0.8; total time=  11.5s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=250, subsample=0.8; total time=  11.3s
# [CV] END colsample_bytree=0.5, gamma=0.1, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=250, subsample=0.8; total time=  11.3s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=150, subsample=0.6; total time=   4.8s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=150, subsample=0.6; total time=   4.5s
# [CV] END colsample_bytree=0.4, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=150, subsample=0.6; total time=   4.6s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=150, subsample=0.9; total time=   5.1s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=150, subsample=0.9; total time=   4.9s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=150, subsample=0.9; total time=   5.0s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.1, max_depth=7, min_child_weight=2, n_estimators=200, subsample=0.7; total time=   7.3s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.1, max_depth=7, min_child_weight=2, n_estimators=200, subsample=0.7; total time=   7.3s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.1, max_depth=7, min_child_weight=2, n_estimators=200, subsample=0.7; total time=   7.3s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.9; total time=   6.1s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.9; total time=   6.2s
# [CV] END colsample_bytree=0.5, gamma=0.3, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.9; total time=   6.4s
# [CV] END colsample_bytree=0.4, gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.9; total time=   6.3s
# [CV] END colsample_bytree=0.4, gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.9; total time=   6.3s
# [CV] END colsample_bytree=0.4, gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=4, n_estimators=200, subsample=0.9; total time=   6.3s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.1, max_depth=3, min_child_weight=2, n_estimators=250, subsample=0.6; total time=   7.4s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.1, max_depth=3, min_child_weight=2, n_estimators=250, subsample=0.6; total time=   7.5s
# [CV] END colsample_bytree=0.7, gamma=0.4, learning_rate=0.1, max_depth=3, min_child_weight=2, n_estimators=250, subsample=0.6; total time=   7.5s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   6.9s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   6.5s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   7.0s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.02, max_depth=4, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   6.2s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.02, max_depth=4, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   6.1s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.02, max_depth=4, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   6.0s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=150, subsample=0.9; total time=   5.2s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=150, subsample=0.9; total time=   5.1s
# [CV] END colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=150, subsample=0.9; total time=   4.0s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.02, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   6.7s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.02, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   6.6s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.02, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   6.5s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.02, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.8; total time=   3.7s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.02, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.8; total time=   3.1s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.02, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=150, subsample=0.9; total time=   5.0s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=150, subsample=0.9; total time=   5.0s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=150, subsample=0.9; total time=   5.2s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.01, max_depth=8, min_child_weight=4, n_estimators=200, subsample=0.8; total time=   7.9s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.01, max_depth=8, min_child_weight=4, n_estimators=200, subsample=0.8; total time=   7.7s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.01, max_depth=8, min_child_weight=4, n_estimators=200, subsample=0.8; total time=   9.6s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.02, max_depth=4, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   6.2s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.02, max_depth=4, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   6.0s
# [CV] END colsample_bytree=0.3, gamma=0.2, learning_rate=0.02, max_depth=4, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   6.2s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.02, max_depth=8, min_child_weight=3, n_estimators=150, subsample=0.8; total time=   6.6s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.02, max_depth=8, min_child_weight=3, n_estimators=150, subsample=0.8; total time=   6.6s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.02, max_depth=8, min_child_weight=3, n_estimators=150, subsample=0.8; total time=   6.7s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=150, subsample=0.8; total time=   4.4s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=150, subsample=0.8; total time=   4.4s
# [CV] END colsample_bytree=0.5, gamma=0.4, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=150, subsample=0.8; total time=   4.6s
# [CV] END colsample_bytree=0.4, gamma=0, learning_rate=0.02, max_depth=8, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   9.0s
# [CV] END colsample_bytree=0.4, gamma=0, learning_rate=0.02, max_depth=8, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   9.6s
# [CV] END colsample_bytree=0.4, gamma=0, learning_rate=0.02, max_depth=8, min_child_weight=1, n_estimators=200, subsample=0.6; total time=   9.1s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=150, subsample=0.9; total time=   5.5s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=150, subsample=0.9; total time=   5.6s
# [CV] END colsample_bytree=0.6, gamma=0.4, learning_rate=0.1, max_depth=6, min_child_weight=1, n_estimators=150, subsample=0.9; total time=   5.6s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.9; total time=   6.6s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.9; total time=   6.2s
# [CV] END colsample_bytree=0.4, gamma=0.3, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.9; total time=   6.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.02, max_depth=5, min_child_weight=3, n_estimators=250, subsample=0.9; total time=   9.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.02, max_depth=5, min_child_weight=3, n_estimators=250, subsample=0.9; total time=   8.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.02, max_depth=5, min_child_weight=3, n_estimators=250, subsample=0.9; total time=   8.6s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.1, max_depth=7, min_child_weight=2, n_estimators=150, subsample=0.8; total time=   5.8s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.1, max_depth=7, min_child_weight=2, n_estimators=150, subsample=0.8; total time=   6.0s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.1, max_depth=7, min_child_weight=2, n_estimators=150, subsample=0.8; total time=   6.4s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.05, max_depth=7, min_child_weight=4, n_estimators=250, subsample=0.7; total time=   9.5s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.05, max_depth=7, min_child_weight=4, n_estimators=250, subsample=0.7; total time=   9.4s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.05, max_depth=7, min_child_weight=4, n_estimators=250, subsample=0.7; total time=   9.5s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.01, max_depth=6, min_child_weight=2, n_estimators=150, subsample=0.9; total time=   5.3s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.01, max_depth=6, min_child_weight=2, n_estimators=150, subsample=0.9; total time=   5.3s
# [CV] END colsample_bytree=0.4, gamma=0.4, learning_rate=0.01, max_depth=6, min_child_weight=2, n_estimators=150, subsample=0.9; total time=   5.5s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=100, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=100, subsample=0.8; total time=   3.2s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=100, subsample=0.8; total time=   3.1s
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.02, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   7.5s
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.02, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   7.5s
# [CV] END colsample_bytree=0.5, gamma=0.2, learning_rate=0.02, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   7.6s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.01, max_depth=6, min_child_weight=2, n_estimators=150, subsample=0.7; total time=   5.4s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.01, max_depth=6, min_child_weight=2, n_estimators=150, subsample=0.7; total time=   5.5s
# [CV] END colsample_bytree=0.4, gamma=0.2, learning_rate=0.01, max_depth=6, min_child_weight=2, n_estimators=150, subsample=0.7; total time=   5.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.8; total time=   9.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.8; total time=   9.0s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=8, min_child_weight=2, n_estimators=200, subsample=0.8; total time=   9.0s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.02, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   3.0s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.02, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   3.1s
# [CV] END colsample_bytree=0.3, gamma=0.3, learning_rate=0.02, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   3.1s

# %%
best_clf
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.6, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=2, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
rf_prediction = best_clf.predict(X_test)
metrics.accuracy_score(y_test, rf_prediction)
# Out:
# 0.5822943046500351

# %%
metrics.f
