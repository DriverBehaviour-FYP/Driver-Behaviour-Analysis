# %%
import pandas as pd
import numpy as np
import requests
from requests.exceptions import Timeout
import time
import os

# %%
os.listdir("../../data/Raw-GPS-data-Kandy-Buses/preprocessed-data-digana_2021_10/")
# Out:
# ['bus_stop_all_points.csv',
#  'bus_stop_all_points.xlsx',
#  'bus_trips.csv',
#  'bus_trip_all_points.csv',
#  'bus_trip_all_points.xlsx',
#  'bus_trip_all_zone_points.csv',
#  'bus_trip_all_zone_points.xlsx',
#  'bus_trip_with_max_speed.csv',
#  'clearn.csv',
#  'clearn_gps_data_with_trip_id.csv',
#  'trip_ends.csv']

# %%
def get_directions(origin, destination, timeout=5, max_retries=3):
    base_url = "https://maps.googleapis.com/maps/api/directions/json"

    params = {
        'origin': f"{origin[0]},{origin[1]}",
        'destination': f"{destination[0]},{destination[1]}",
        'key': "AIzaSyCz5uw3SrNct_Dqw6S6_D6AokxUVp0_hAg",
    }

    for retry in range(max_retries):
        try:
            response = requests.get(base_url, params=params, timeout=timeout)
            response.raise_for_status()  # Raise an HTTPError for bad responses

            # Parse and return the JSON response
            return response.json()
        except Timeout:
            print(f"Timeout error. Retrying... ({retry + 1}/{max_retries})")
        except requests.exceptions.RequestException as e:
            print(f"Error: {e}")

    # If all retries fail, return None or handle as needed
    print(f"Failed after {max_retries} retries. Returning None.")
    return None

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# this is the initial segmentation component with this component we can segment all the trips into segments
class TripSegmenterByDistance( BaseEstimator, TransformerMixin):
  def fit(self, X, y=None):
    return self

  def transform(self, X):
    gps_data_ts, bus_trips_ts = X
    new_records = []  # List to store the split records
    gps_data_ts['d_segment_id'] = None
    segment_id = 1

    total_distance = 16800   # is the distance in meters from Digana to Kandy
    rng = 1000

    start_point =

    for distance in range(rng, total_distance//rng, rng):
      for index, row in bus_trips_ts.iterrows():
        max_index = np.max(np.where(gps_data_ts['trip_id'] == row['trip_id']))
        min_index = np.min(np.where(gps_data_ts['trip_id'] == row['trip_id']))

        margin = min_index

        while(margin < max_index):
          margin, distance = self.binary_search(gps_data_ts, min_index, max_index, 1000);
          # print(f"margin: {margin}, distance: {distance}")
          # break
          gps_data_ts.loc[min_index:margin, 'd_segment_id'] = segment_id

          min_index = margin + 1
          segment_id+=1
    return gps_data_ts


  def binary_search(self, gps_data, starting_ind, max_ind, seg_distance):
    low, high = starting_ind, max_ind
    early_mid, early_distance = None, None
    rounds = 0
    while low<=high:
      if rounds>0:
        early_mid, early_distance = mid, distance
      mid = (low + high)//2
      # take the response from google maps API
      origin = (gps_data.iloc[starting_ind]['latitude'], gps_data.iloc[starting_ind]['longitude'])
      destination = (gps_data.iloc[mid]['latitude'], gps_data.iloc[mid]['longitude'])
      res  = get_directions(origin, destination)
      distance = res['routes'][0]['legs'][0]['distance']['value']
      # print(f"Distance: {distance}   Mid: {mid}")

      if distance>= seg_distance - 20 and distance <= seg_distance + 20:
        # print(res['routes'][0]['legs'][0])
        return mid, distance
      elif distance < seg_distance - 20:
        low = mid + 1
      elif distance > seg_distance + 20:
        high = mid - 1
      rounds+=1
    # print(f"Er dis: {early_distance}  er_mid: {early_mid}")
    if early_mid!=None and abs(seg_distance-early_distance) <= abs(seg_distance-distance):
      return early_mid, early_distance
    else:
      return mid, distance

# %%
bus_trips = pd.read_csv("../../data/Raw-GPS-data-Kandy-Buses/preprocessed-data-digana_2021_10/bus_trips.csv")
gps_data = pd.read_csv("../../data/Raw-GPS-data-Kandy-Buses/preprocessed-data-digana_2021_10/clearn_gps_data_with_trip_id.csv")

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from geopy.distance import geodesic

# this is the secondary segmentation component which creates the DataFrame of route points along the track
class TripSegmenterByDistance( BaseEstimator, TransformerMixin):

  def __init__(self, month_pointer, path_to_temp, previous_segment_max,path_to_terminals, precision=0.01, seg_pointer = '1000M', ):
    self.month_pointer = month_pointer
    self.path_to_temp = path_to_temp
    self.previous_segment_max = previous_segment_max
    self.seg_distance = int(seg_pointer[:-1])
    self.seg_pointer = seg_pointer
    self.path_to_terminals = path_to_terminals
    self.precision = precision

  def fit(self, X, y=None):
    return self
  
  def calculate_split_df(self, gps_data_ts, bus_trips_ts):
    # load terminals so that starting location and ending location is known
    terminals = pd.read_csv(self.path_to_terminals)

    # load starting point and ending points from the terminals df
    starting_point = (terminals.loc[0]['latitude'], terminals.iloc[0]['longitude'])
    ending_point  = (terminals.loc[1]['latitude'], terminals.iloc[1]['longitude'])

    processing_point = starting_point

    # select trips that are driven to the selected direction
    bus_trips_dir_1 = bus_trips_ts[(bus_trips_ts['start_terminal']==terminals.loc[0]['terminal_id']) & (bus_trips_ts['end_terminal']==terminals.loc[1]['terminal_id'])]

    # splitting points that would identify will store here
    split_points = []

    split_point_id = 1

    # run until complete route is segmented
    # get the distance from currently processing point to ending point and compare with segment length
    while(get_directions(processing_point, ending_point)['routes'][0]['legs'][0]['distance']['value']>self.seg_distance):
      print("Processing: ",split_point_id)
      # assign a ID to the split point
      split_point = {
        'split_point_id': split_point_id
      }
      # iterate through the bus trips df for the selected trips
      for index, row in bus_trips_dir_1.iterrows():
        max_index = np.max(np.where(gps_data_ts['trip_id'] == row['trip_id']))
        min_index = np.min(np.where(gps_data_ts['trip_id'] == row['trip_id']))

        margin, distance = self.binary_search(gps_data_ts,processing_point, min_index, max_index, ending_point)
        print(f"margin: {margin}, distance: {distance}")
        if abs(self.seg_distance - distance)/self.seg_distance <= self.precision:
          split_point['latitude'] = gps_data_ts.iloc[margin]['latitude']
          split_point['longitude'] = gps_data_ts.iloc[margin]['longitude']
          break

      # append the split points to the output list
      split_points.append(split_point)
      
      # increment the id
      split_point_id+=1

      processing_point = (split_point['latitude'], split_point['longitude'])
    
    # take splitting points into a dataframe
    split_points_df = pd.DataFrame(split_points)

    return split_points_df

  def transform(self, X):
    # splits data into gps data and the bus trips
    gps_data_ts, bus_trips_ts = X

    split_points_file_path = "./segment_split_points.csv"
    if os.path.exists(split_points_file_path):
      split_points_df = pd.read_csv(split_points_file_path)
      print("Loaded splitting points from cache")
    else:
      split_points_df = self.calculate_split_df(gps_data_ts, bus_trips_ts)
    
    # initialize segment ids of gps data to None
    gps_data_ts['segment_id'] = np.nan

    # segment_id for the gps_data ans segments df
    segment_id = self.previous_segment_max + 1

    for index, row in bus_trips_ts.iterrows():
      print(f"Processing trip-ID: {index+1} with dir: {row['direction']}")
      # get the maximum and minimum indexes of trip's gps points
      max_index = np.max(np.where(gps_data_ts['trip_id'] == row['trip_id']))
      min_index = np.min(np.where(gps_data_ts['trip_id'] == row['trip_id']))

      # take a copy from split points df to store buffer points
      if row['direction']==1:
        buff = split_points_df[::].copy()
      else:
        buff = split_points_df[::-1].reset_index(drop=True).copy()
    
      # initialize the gps_data_index to nan
      buff['gps_data_index'] = np.nan

      # filling out gps_data_ts's index to split points
      for ind, split_row in buff.iterrows():
        split_point = (split_row['latitude'], split_row['longitude'])
        for i in range(min_index, max_index+1):
          gps_point = (gps_data_ts.iloc[i]['latitude'], gps_data_ts.iloc[i]['longitude'])

          dist = geodesic(split_point, gps_point).meters
          if dist<=100:
            buff.loc[ind,'gps_data_index'] = i
            break
      
      # assign gps_data_ts the segment_ids
      for i in range(0, len(buff)):
        start = min_index if i==0 else buff.loc[i-1]['gps_data_index']
        end = buff.loc[i]['gps_data_index']

        if (not start) or (not end):
          print("-----------------------------------")
        gps_data_ts.loc[start:end,'segment_id'] = segment_id
        segment_id+=1

        if i== len(buff)-1 :
          gps_data_ts.loc[end:max_index,'segment_id'] = segment_id
          segment_id += 1
    
    return gps_data_ts
      
      

  def binary_search(self, gps_data, origin,starting_ind, max_ind, terminal_location):
    # low and high is for binary search since there are needed to calculate mid
    low, high = starting_ind, max_ind

    # early distance and mid is stored since it is useful when returning the optimal mid and distance
    early_mid, early_distance = None, None

    # tracking rounds since to store early mid and early distance, rounds > 0
    rounds = 0

    while low<=high:
      if rounds>0:
        early_mid, early_distance = mid, distance
      mid = (low + high)//2

      # assigning destination
      destination = (gps_data.iloc[mid]['latitude'], gps_data.iloc[mid]['longitude'])

      origin_to_terminal = get_directions(origin, terminal_location)['routes'][0]['legs'][0]['distance']['value']
      destination_to_teminal = get_directions(destination, terminal_location)['routes'][0]['legs'][0]['distance']['value']

      if origin_to_terminal<=destination_to_teminal:
        low = mid+1
        continue

      # calling the API
      res  = get_directions(origin, destination)

      # extract out distance
      distance = res['routes'][0]['legs'][0]['distance']['value']

      if distance>= self.seg_distance - 20 and distance <= self.seg_distance + 20:
        # print(res['routes'][0]['legs'][0])
        return mid, distance
      elif distance < self.seg_distance - 20:
        low = mid + 1
      elif distance > self.seg_distance + 20:
        high = mid - 1
      rounds+=1
    # print(f"Er dis: {early_distance}  er_mid: {early_mid}")
    if early_mid!=None and abs(self.seg_distance-early_distance) <= abs(self.seg_distance-distance):
      return early_mid, early_distance
    else:
      return mid, distance

# %%
comp = TripSegmenterByDistance("Dinana_2021_10", "tempPath", 0 , "../../data/Raw-GPS-data-Kandy-Buses/more/bus_terminals_654.csv",0.01, "1000M")
result_df = comp.transform((gps_data, bus_trips))
# Out:
# Loaded splitting points from cache
# Processing trip-ID: 1 with dir: 2
# -----------------------------------
# Processing trip-ID: 2 with dir: 1
# Processing trip-ID: 3 with dir: 2
# Processing trip-ID: 4 with dir: 1
# Processing trip-ID: 5 with dir: 2
# Processing trip-ID: 6 with dir: 1
# Processing trip-ID: 7 with dir: 2
# Processing trip-ID: 8 with dir: 1
# Processing trip-ID: 9 with dir: 2
# Processing trip-ID: 10 with dir: 1
# Processing trip-ID: 11 with dir: 2
# Processing trip-ID: 12 with dir: 1
# Processing trip-ID: 13 with dir: 2
# Processing trip-ID: 14 with dir: 1
# Processing trip-ID: 15 with dir: 2
# Processing trip-ID: 16 with dir: 1
# Processing trip-ID: 17 with dir: 2
# Processing trip-ID: 18 with dir: 1
# Processing trip-ID: 19 with dir: 2
# Processing trip-ID: 20 with dir: 1
# Processing trip-ID: 21 with dir: 2
# Processing trip-ID: 22 with dir: 1
# Processing trip-ID: 23 with dir: 2
# Processing trip-ID: 24 with dir: 1
# Processing trip-ID: 25 with dir: 2
# Processing trip-ID: 26 with dir: 1
# Processing trip-ID: 27 with dir: 2
# Processing trip-ID: 28 with dir: 1
# Processing trip-ID: 29 with dir: 2
# Processing trip-ID: 30 with dir: 1
# Processing trip-ID: 31 with dir: 2
# Processing trip-ID: 32 with dir: 1
# Processing trip-ID: 33 with dir: 2
# Processing trip-ID: 34 with dir: 1
# Processing trip-ID: 35 with dir: 2
# Processing trip-ID: 36 with dir: 1
# Processing trip-ID: 37 with dir: 2
# Processing trip-ID: 38 with dir: 1
# Processing trip-ID: 39 with dir: 2
# Processing trip-ID: 40 with dir: 1
# Processing trip-ID: 41 with dir: 2
# Processing trip-ID: 42 with dir: 1
# Processing trip-ID: 43 with dir: 2
# Processing trip-ID: 44 with dir: 1
# Processing trip-ID: 45 with dir: 2
# Processing trip-ID: 46 with dir: 1
# Processing trip-ID: 47 with dir: 2
# Processing trip-ID: 48 with dir: 1
# Processing trip-ID: 49 with dir: 2
# Processing trip-ID: 50 with dir: 1
# Processing trip-ID: 51 with dir: 2
# Processing trip-ID: 52 with dir: 1
# Processing trip-ID: 53 with dir: 2
# Processing trip-ID: 54 with dir: 1
# Processing trip-ID: 55 with dir: 2
# Processing trip-ID: 56 with dir: 1
# Processing trip-ID: 57 with dir: 2
# Processing trip-ID: 58 with dir: 1
# Processing trip-ID: 59 with dir: 2
# Processing trip-ID: 60 with dir: 1
# Processing trip-ID: 61 with dir: 2
# Processing trip-ID: 62 with dir: 1
# Processing trip-ID: 63 with dir: 2
# Processing trip-ID: 64 with dir: 1
# Processing trip-ID: 65 with dir: 2
# Processing trip-ID: 66 with dir: 1
# Processing trip-ID: 67 with dir: 2
# Processing trip-ID: 68 with dir: 1
# Processing trip-ID: 69 with dir: 2
# Processing trip-ID: 70 with dir: 1
# Processing trip-ID: 71 with dir: 2
# Processing trip-ID: 72 with dir: 1
# Processing trip-ID: 73 with dir: 2
# Processing trip-ID: 74 with dir: 1
# Processing trip-ID: 75 with dir: 2
# Processing trip-ID: 76 with dir: 1
# Processing trip-ID: 77 with dir: 2
# Processing trip-ID: 78 with dir: 1
# Processing trip-ID: 79 with dir: 2
# Processing trip-ID: 80 with dir: 1
# Processing trip-ID: 81 with dir: 2
# Processing trip-ID: 82 with dir: 2
# Processing trip-ID: 83 with dir: 1
# Processing trip-ID: 84 with dir: 2
# Processing trip-ID: 85 with dir: 1
# Processing trip-ID: 86 with dir: 1
# Processing trip-ID: 87 with dir: 1
# Processing trip-ID: 88 with dir: 2
# Processing trip-ID: 89 with dir: 1
# Processing trip-ID: 90 with dir: 2
# Processing trip-ID: 91 with dir: 1
# Processing trip-ID: 92 with dir: 2
# Processing trip-ID: 93 with dir: 1
# Processing trip-ID: 94 with dir: 2
# Processing trip-ID: 95 with dir: 1
# Processing trip-ID: 96 with dir: 2
# Processing trip-ID: 97 with dir: 1
# Processing trip-ID: 98 with dir: 2
# Processing trip-ID: 99 with dir: 1
# Processing trip-ID: 100 with dir: 2
# Processing trip-ID: 101 with dir: 1
# Processing trip-ID: 102 with dir: 2
# Processing trip-ID: 103 with dir: 1
# Processing trip-ID: 104 with dir: 2
# Processing trip-ID: 105 with dir: 1
# Processing trip-ID: 106 with dir: 2
# Processing trip-ID: 107 with dir: 1
# Processing trip-ID: 108 with dir: 2
# Processing trip-ID: 109 with dir: 1
# Processing trip-ID: 110 with dir: 2
# Processing trip-ID: 111 with dir: 1
# Processing trip-ID: 112 with dir: 2
# Processing trip-ID: 113 with dir: 1
# Processing trip-ID: 114 with dir: 2
# Processing trip-ID: 115 with dir: 1
# Processing trip-ID: 116 with dir: 2
# Processing trip-ID: 117 with dir: 1
# Processing trip-ID: 118 with dir: 2
# Processing trip-ID: 119 with dir: 1
# Processing trip-ID: 120 with dir: 2
# Processing trip-ID: 121 with dir: 1
# Processing trip-ID: 122 with dir: 2
# Processing trip-ID: 123 with dir: 1
# Processing trip-ID: 124 with dir: 2
# Processing trip-ID: 125 with dir: 1
# Processing trip-ID: 126 with dir: 2
# Processing trip-ID: 127 with dir: 1
# Processing trip-ID: 128 with dir: 2
# Processing trip-ID: 129 with dir: 1
# Processing trip-ID: 130 with dir: 2
# Processing trip-ID: 131 with dir: 1
# Processing trip-ID: 132 with dir: 2
# Processing trip-ID: 133 with dir: 1
# Processing trip-ID: 134 with dir: 2
# Processing trip-ID: 135 with dir: 1
# Processing trip-ID: 136 with dir: 2
# Processing trip-ID: 137 with dir: 1
# Processing trip-ID: 138 with dir: 2
# Processing trip-ID: 139 with dir: 1
# Processing trip-ID: 140 with dir: 2
# Processing trip-ID: 141 with dir: 1
# Processing trip-ID: 142 with dir: 2
# Processing trip-ID: 143 with dir: 1
# Processing trip-ID: 144 with dir: 2
# Processing trip-ID: 145 with dir: 1
# Processing trip-ID: 146 with dir: 2
# Processing trip-ID: 147 with dir: 1
# Processing trip-ID: 148 with dir: 2
# Processing trip-ID: 149 with dir: 1
# Processing trip-ID: 150 with dir: 2
# Processing trip-ID: 151 with dir: 1
# Processing trip-ID: 152 with dir: 2
# Processing trip-ID: 153 with dir: 1
# Processing trip-ID: 154 with dir: 2
# Processing trip-ID: 155 with dir: 1
# Processing trip-ID: 156 with dir: 2
# Processing trip-ID: 157 with dir: 1
# Processing trip-ID: 158 with dir: 2
# Processing trip-ID: 159 with dir: 1
# Processing trip-ID: 160 with dir: 2
# Processing trip-ID: 161 with dir: 1
# Processing trip-ID: 162 with dir: 2
# Processing trip-ID: 163 with dir: 1
# Processing trip-ID: 164 with dir: 2
# Processing trip-ID: 165 with dir: 1
# Processing trip-ID: 166 with dir: 2
# Processing trip-ID: 167 with dir: 1
# Processing trip-ID: 168 with dir: 1
# Processing trip-ID: 169 with dir: 2
# Processing trip-ID: 170 with dir: 1
# Processing trip-ID: 171 with dir: 2
# Processing trip-ID: 172 with dir: 1
# Processing trip-ID: 173 with dir: 2
# Processing trip-ID: 174 with dir: 1
# Processing trip-ID: 175 with dir: 2
# Processing trip-ID: 176 with dir: 1
# Processing trip-ID: 177 with dir: 2
# Processing trip-ID: 178 with dir: 2
# Processing trip-ID: 179 with dir: 1
# Processing trip-ID: 180 with dir: 2
# Processing trip-ID: 181 with dir: 1
# Processing trip-ID: 182 with dir: 2
# Processing trip-ID: 183 with dir: 1
# Processing trip-ID: 184 with dir: 2
# Processing trip-ID: 185 with dir: 1
# Processing trip-ID: 186 with dir: 2
# Processing trip-ID: 187 with dir: 1
# Processing trip-ID: 188 with dir: 2
# Processing trip-ID: 189 with dir: 1
# Processing trip-ID: 190 with dir: 2
# Processing trip-ID: 191 with dir: 1
# Processing trip-ID: 192 with dir: 2
# Processing trip-ID: 193 with dir: 1
# Processing trip-ID: 194 with dir: 2
# Processing trip-ID: 195 with dir: 1
# Processing trip-ID: 196 with dir: 2
# Processing trip-ID: 197 with dir: 1
# Processing trip-ID: 198 with dir: 2
# Processing trip-ID: 199 with dir: 1
# Processing trip-ID: 200 with dir: 2
# Processing trip-ID: 201 with dir: 1
# Processing trip-ID: 202 with dir: 2
# Processing trip-ID: 203 with dir: 1
# Processing trip-ID: 204 with dir: 2
# Processing trip-ID: 205 with dir: 1
# Processing trip-ID: 206 with dir: 2
# Processing trip-ID: 207 with dir: 1
# Processing trip-ID: 208 with dir: 2
# Processing trip-ID: 209 with dir: 1
# Processing trip-ID: 210 with dir: 2
# Processing trip-ID: 211 with dir: 1
# Processing trip-ID: 212 with dir: 2
# Processing trip-ID: 213 with dir: 1
# Processing trip-ID: 214 with dir: 2
# Processing trip-ID: 215 with dir: 1
# Processing trip-ID: 216 with dir: 2
# Processing trip-ID: 217 with dir: 1
# Processing trip-ID: 218 with dir: 2
# Processing trip-ID: 219 with dir: 1
# Processing trip-ID: 220 with dir: 2
# Processing trip-ID: 221 with dir: 1
# Processing trip-ID: 222 with dir: 2
# Processing trip-ID: 223 with dir: 1
# Processing trip-ID: 224 with dir: 2
# Processing trip-ID: 225 with dir: 1
# Processing trip-ID: 226 with dir: 2
# Processing trip-ID: 227 with dir: 1
# Processing trip-ID: 228 with dir: 2
# Processing trip-ID: 229 with dir: 1
# Processing trip-ID: 230 with dir: 2
# Processing trip-ID: 231 with dir: 1
# Processing trip-ID: 232 with dir: 2
# Processing trip-ID: 233 with dir: 1
# Processing trip-ID: 234 with dir: 2
# Processing trip-ID: 235 with dir: 1
# Processing trip-ID: 236 with dir: 2
# Processing trip-ID: 237 with dir: 1
# Processing trip-ID: 238 with dir: 2
# Processing trip-ID: 239 with dir: 1
# Processing trip-ID: 240 with dir: 2
# Processing trip-ID: 241 with dir: 1
# Processing trip-ID: 242 with dir: 1
# Processing trip-ID: 243 with dir: 2
# Processing trip-ID: 244 with dir: 1
# Processing trip-ID: 245 with dir: 2
# Processing trip-ID: 246 with dir: 1
# Processing trip-ID: 247 with dir: 2
# Processing trip-ID: 248 with dir: 1
# Processing trip-ID: 249 with dir: 1
# Processing trip-ID: 250 with dir: 2
# Processing trip-ID: 251 with dir: 1
# Processing trip-ID: 252 with dir: 2
# Processing trip-ID: 253 with dir: 1
# Processing trip-ID: 254 with dir: 2
# Processing trip-ID: 255 with dir: 1
# Processing trip-ID: 256 with dir: 2
# Processing trip-ID: 257 with dir: 1
# Processing trip-ID: 258 with dir: 2
# Processing trip-ID: 259 with dir: 1
# Processing trip-ID: 260 with dir: 2
# Processing trip-ID: 261 with dir: 1
# Processing trip-ID: 262 with dir: 2
# Processing trip-ID: 263 with dir: 1
# Processing trip-ID: 264 with dir: 2
# Processing trip-ID: 265 with dir: 1
# Processing trip-ID: 266 with dir: 2
# Processing trip-ID: 267 with dir: 1
# Processing trip-ID: 268 with dir: 2
# Processing trip-ID: 269 with dir: 2
# Processing trip-ID: 270 with dir: 1
# Processing trip-ID: 271 with dir: 2
# Processing trip-ID: 272 with dir: 1
# Processing trip-ID: 273 with dir: 2
# Processing trip-ID: 274 with dir: 1
# Processing trip-ID: 275 with dir: 2
# Processing trip-ID: 276 with dir: 1
# Processing trip-ID: 277 with dir: 2
# Processing trip-ID: 278 with dir: 1
# Processing trip-ID: 279 with dir: 2
# Processing trip-ID: 280 with dir: 1
# Processing trip-ID: 281 with dir: 2
# Processing trip-ID: 282 with dir: 1
# Processing trip-ID: 283 with dir: 2
# Processing trip-ID: 284 with dir: 1
# Processing trip-ID: 285 with dir: 2
# Processing trip-ID: 286 with dir: 1
# Processing trip-ID: 287 with dir: 2
# Processing trip-ID: 288 with dir: 1
# Processing trip-ID: 289 with dir: 2
# Processing trip-ID: 290 with dir: 1
# Processing trip-ID: 291 with dir: 2
# Processing trip-ID: 292 with dir: 1
# Processing trip-ID: 293 with dir: 2
# Processing trip-ID: 294 with dir: 1
# Processing trip-ID: 295 with dir: 2
# Processing trip-ID: 296 with dir: 1
# Processing trip-ID: 297 with dir: 2
# Processing trip-ID: 298 with dir: 1
# Processing trip-ID: 299 with dir: 2
# Processing trip-ID: 300 with dir: 1
# Processing trip-ID: 301 with dir: 2
# Processing trip-ID: 302 with dir: 1
# Processing trip-ID: 303 with dir: 2
# Processing trip-ID: 304 with dir: 1
# Processing trip-ID: 305 with dir: 2
# Processing trip-ID: 306 with dir: 1
# Processing trip-ID: 307 with dir: 2
# Processing trip-ID: 308 with dir: 1
# Processing trip-ID: 309 with dir: 2
# Processing trip-ID: 310 with dir: 1
# Processing trip-ID: 311 with dir: 2
# Processing trip-ID: 312 with dir: 1
# Processing trip-ID: 313 with dir: 2
# Processing trip-ID: 314 with dir: 1
# Processing trip-ID: 315 with dir: 2
# Processing trip-ID: 316 with dir: 1
# Processing trip-ID: 317 with dir: 2
# Processing trip-ID: 318 with dir: 1
# Processing trip-ID: 319 with dir: 2
# Processing trip-ID: 320 with dir: 1
# Processing trip-ID: 321 with dir: 2
# Processing trip-ID: 322 with dir: 1
# Processing trip-ID: 323 with dir: 2
# Processing trip-ID: 324 with dir: 1
# Processing trip-ID: 325 with dir: 2
# Processing trip-ID: 326 with dir: 1
# Processing trip-ID: 327 with dir: 2
# Processing trip-ID: 328 with dir: 1
# Processing trip-ID: 329 with dir: 2
# Processing trip-ID: 330 with dir: 1
# Processing trip-ID: 331 with dir: 2
# Processing trip-ID: 332 with dir: 1
# Processing trip-ID: 333 with dir: 2
# Processing trip-ID: 334 with dir: 1
# Processing trip-ID: 335 with dir: 2
# Processing trip-ID: 336 with dir: 1
# Processing trip-ID: 337 with dir: 2
# Processing trip-ID: 338 with dir: 1
# Processing trip-ID: 339 with dir: 2
# Processing trip-ID: 340 with dir: 1
# Processing trip-ID: 341 with dir: 2
# Processing trip-ID: 342 with dir: 1
# Processing trip-ID: 343 with dir: 2
# Processing trip-ID: 344 with dir: 1
# Processing trip-ID: 345 with dir: 2
# Processing trip-ID: 346 with dir: 1
# Processing trip-ID: 347 with dir: 2
# Processing trip-ID: 348 with dir: 1
# Processing trip-ID: 349 with dir: 2
# Processing trip-ID: 350 with dir: 1
# Processing trip-ID: 351 with dir: 2
# Processing trip-ID: 352 with dir: 1
# Processing trip-ID: 353 with dir: 2
# Processing trip-ID: 354 with dir: 1
# Processing trip-ID: 355 with dir: 2
# Processing trip-ID: 356 with dir: 1
# Processing trip-ID: 357 with dir: 2
# Processing trip-ID: 358 with dir: 1
# Processing trip-ID: 359 with dir: 2
# Processing trip-ID: 360 with dir: 1
# Processing trip-ID: 361 with dir: 2
# Processing trip-ID: 362 with dir: 1
# Processing trip-ID: 363 with dir: 2
# Processing trip-ID: 364 with dir: 1
# Processing trip-ID: 365 with dir: 2
# Processing trip-ID: 366 with dir: 1
# Processing trip-ID: 367 with dir: 2
# Processing trip-ID: 368 with dir: 1
# Processing trip-ID: 369 with dir: 2
# Processing trip-ID: 370 with dir: 1
# Processing trip-ID: 371 with dir: 2
# Processing trip-ID: 372 with dir: 1
# Processing trip-ID: 373 with dir: 2
# Processing trip-ID: 374 with dir: 1
# Processing trip-ID: 375 with dir: 2
# Processing trip-ID: 376 with dir: 1
# Processing trip-ID: 377 with dir: 2
# Processing trip-ID: 378 with dir: 1
# Processing trip-ID: 379 with dir: 2
# Processing trip-ID: 380 with dir: 1
# Processing trip-ID: 381 with dir: 2
# Processing trip-ID: 382 with dir: 1
# Processing trip-ID: 383 with dir: 2
# Processing trip-ID: 384 with dir: 1
# Processing trip-ID: 385 with dir: 2
# Processing trip-ID: 386 with dir: 1
# Processing trip-ID: 387 with dir: 2
# Processing trip-ID: 388 with dir: 1
# Processing trip-ID: 389 with dir: 2
# Processing trip-ID: 390 with dir: 1
# Processing trip-ID: 391 with dir: 2
# Processing trip-ID: 392 with dir: 1
# Processing trip-ID: 393 with dir: 2
# Processing trip-ID: 394 with dir: 1
# Processing trip-ID: 395 with dir: 2
# Processing trip-ID: 396 with dir: 1
# Processing trip-ID: 397 with dir: 2
# Processing trip-ID: 398 with dir: 1
# Processing trip-ID: 399 with dir: 2
# Processing trip-ID: 400 with dir: 1
# Processing trip-ID: 401 with dir: 2
# Processing trip-ID: 402 with dir: 1
# Processing trip-ID: 403 with dir: 2
# Processing trip-ID: 404 with dir: 1
# Processing trip-ID: 405 with dir: 2
# Processing trip-ID: 406 with dir: 1
# Processing trip-ID: 407 with dir: 2
# Processing trip-ID: 408 with dir: 1
# Processing trip-ID: 409 with dir: 2
# Processing trip-ID: 410 with dir: 1
# Processing trip-ID: 411 with dir: 2
# Processing trip-ID: 412 with dir: 1
# Processing trip-ID: 413 with dir: 2
# Processing trip-ID: 414 with dir: 1
# Processing trip-ID: 415 with dir: 2
# Processing trip-ID: 416 with dir: 1
# Processing trip-ID: 417 with dir: 2
# Processing trip-ID: 418 with dir: 1
# Processing trip-ID: 419 with dir: 2
# Processing trip-ID: 420 with dir: 1
# Processing trip-ID: 421 with dir: 2
# Processing trip-ID: 422 with dir: 1
# Processing trip-ID: 423 with dir: 2
# Processing trip-ID: 424 with dir: 1
# Processing trip-ID: 425 with dir: 2
# Processing trip-ID: 426 with dir: 1
# Processing trip-ID: 427 with dir: 2
# Processing trip-ID: 428 with dir: 1
# Processing trip-ID: 429 with dir: 2
# Processing trip-ID: 430 with dir: 1
# Processing trip-ID: 431 with dir: 2
# Processing trip-ID: 432 with dir: 1
# Processing trip-ID: 433 with dir: 2
# Processing trip-ID: 434 with dir: 1
# Processing trip-ID: 435 with dir: 2
# Processing trip-ID: 436 with dir: 1
# Processing trip-ID: 437 with dir: 2
# Processing trip-ID: 438 with dir: 1
# Processing trip-ID: 439 with dir: 2
# Processing trip-ID: 440 with dir: 1
# Processing trip-ID: 441 with dir: 2
# Processing trip-ID: 442 with dir: 1
# Processing trip-ID: 443 with dir: 2
# Processing trip-ID: 444 with dir: 1
# Processing trip-ID: 445 with dir: 2
# Processing trip-ID: 446 with dir: 1
# Processing trip-ID: 447 with dir: 2
# Processing trip-ID: 448 with dir: 1
# Processing trip-ID: 449 with dir: 2
# Processing trip-ID: 450 with dir: 1
# Processing trip-ID: 451 with dir: 2
# Processing trip-ID: 452 with dir: 1
# Processing trip-ID: 453 with dir: 2
# Processing trip-ID: 454 with dir: 1
# Processing trip-ID: 455 with dir: 2
# Processing trip-ID: 456 with dir: 1
# Processing trip-ID: 457 with dir: 2
# Processing trip-ID: 458 with dir: 1
# Processing trip-ID: 459 with dir: 2
# Processing trip-ID: 460 with dir: 1
# Processing trip-ID: 461 with dir: 2
# Processing trip-ID: 462 with dir: 1
# Processing trip-ID: 463 with dir: 2
# Processing trip-ID: 464 with dir: 1
# Processing trip-ID: 465 with dir: 2
# Processing trip-ID: 466 with dir: 1
# Processing trip-ID: 467 with dir: 2
# Processing trip-ID: 468 with dir: 1
# Processing trip-ID: 469 with dir: 2
# Processing trip-ID: 470 with dir: 1
# Processing trip-ID: 471 with dir: 2
# Processing trip-ID: 472 with dir: 1
# Processing trip-ID: 473 with dir: 2
# Processing trip-ID: 474 with dir: 1
# Processing trip-ID: 475 with dir: 2
# Processing trip-ID: 476 with dir: 1
# Processing trip-ID: 477 with dir: 2
# Processing trip-ID: 478 with dir: 1
# Processing trip-ID: 479 with dir: 2
# Processing trip-ID: 480 with dir: 1
# Processing trip-ID: 481 with dir: 2
# Processing trip-ID: 482 with dir: 2
# Processing trip-ID: 483 with dir: 1
# Processing trip-ID: 484 with dir: 2
# Processing trip-ID: 485 with dir: 1
# Processing trip-ID: 486 with dir: 2
# Processing trip-ID: 487 with dir: 1
# Processing trip-ID: 488 with dir: 2
# Processing trip-ID: 489 with dir: 1
# Processing trip-ID: 490 with dir: 2
# Processing trip-ID: 491 with dir: 1
# Processing trip-ID: 492 with dir: 2
# Processing trip-ID: 493 with dir: 1
# Processing trip-ID: 494 with dir: 2
# Processing trip-ID: 495 with dir: 1
# Processing trip-ID: 496 with dir: 2
# Processing trip-ID: 497 with dir: 1
# Processing trip-ID: 498 with dir: 2
# Processing trip-ID: 499 with dir: 1
# Processing trip-ID: 500 with dir: 2
# Processing trip-ID: 501 with dir: 1
# Processing trip-ID: 502 with dir: 2
# Processing trip-ID: 503 with dir: 1
# Processing trip-ID: 504 with dir: 2
# Processing trip-ID: 505 with dir: 1
# Processing trip-ID: 506 with dir: 2
# Processing trip-ID: 507 with dir: 1
# Processing trip-ID: 508 with dir: 2
# Processing trip-ID: 509 with dir: 1
# Processing trip-ID: 510 with dir: 2
# Processing trip-ID: 511 with dir: 1
# Processing trip-ID: 512 with dir: 2
# Processing trip-ID: 513 with dir: 1
# Processing trip-ID: 514 with dir: 1
# Processing trip-ID: 515 with dir: 2
# Processing trip-ID: 516 with dir: 1
# Processing trip-ID: 517 with dir: 2
# Processing trip-ID: 518 with dir: 1
# Processing trip-ID: 519 with dir: 2
# Processing trip-ID: 520 with dir: 1
# Processing trip-ID: 521 with dir: 2
# Processing trip-ID: 522 with dir: 1
# Processing trip-ID: 523 with dir: 2
# Processing trip-ID: 524 with dir: 1
# Processing trip-ID: 525 with dir: 2
# Processing trip-ID: 526 with dir: 1
# Processing trip-ID: 527 with dir: 2
# Processing trip-ID: 528 with dir: 1
# Processing trip-ID: 529 with dir: 2
# Processing trip-ID: 530 with dir: 1
# Processing trip-ID: 531 with dir: 2
# Processing trip-ID: 532 with dir: 1
# Processing trip-ID: 533 with dir: 2
# Processing trip-ID: 534 with dir: 1
# Processing trip-ID: 535 with dir: 2
# Processing trip-ID: 536 with dir: 1
# Processing trip-ID: 537 with dir: 2
# Processing trip-ID: 538 with dir: 1
# Processing trip-ID: 539 with dir: 2
# Processing trip-ID: 540 with dir: 1
# Processing trip-ID: 541 with dir: 2
# Processing trip-ID: 542 with dir: 1
# Processing trip-ID: 543 with dir: 2
# Processing trip-ID: 544 with dir: 1
# Processing trip-ID: 545 with dir: 1
# Processing trip-ID: 546 with dir: 2
# Processing trip-ID: 547 with dir: 1
# Processing trip-ID: 548 with dir: 2
# Processing trip-ID: 549 with dir: 1
# Processing trip-ID: 550 with dir: 2
# Processing trip-ID: 551 with dir: 1
# Processing trip-ID: 552 with dir: 1
# Processing trip-ID: 553 with dir: 2
# Processing trip-ID: 554 with dir: 1
# Processing trip-ID: 555 with dir: 2
# Processing trip-ID: 556 with dir: 1
# Processing trip-ID: 557 with dir: 2
# Processing trip-ID: 558 with dir: 1
# Processing trip-ID: 559 with dir: 2
# Processing trip-ID: 560 with dir: 1
# Processing trip-ID: 561 with dir: 2
# Processing trip-ID: 562 with dir: 1
# Processing trip-ID: 563 with dir: 2
# Processing trip-ID: 564 with dir: 1
# Processing trip-ID: 565 with dir: 2
# Processing trip-ID: 566 with dir: 1
# Processing trip-ID: 567 with dir: 2
# Processing trip-ID: 568 with dir: 1
# Processing trip-ID: 569 with dir: 2
# Processing trip-ID: 570 with dir: 1
# Processing trip-ID: 571 with dir: 2
# Processing trip-ID: 572 with dir: 1
# Processing trip-ID: 573 with dir: 2
# Processing trip-ID: 574 with dir: 1
# Processing trip-ID: 575 with dir: 2
# Processing trip-ID: 576 with dir: 1
# Processing trip-ID: 577 with dir: 2
# Processing trip-ID: 578 with dir: 1
# Processing trip-ID: 579 with dir: 2
# Processing trip-ID: 580 with dir: 1
# Processing trip-ID: 581 with dir: 2
# Processing trip-ID: 582 with dir: 1
# Processing trip-ID: 583 with dir: 2
# Processing trip-ID: 584 with dir: 1
# Processing trip-ID: 585 with dir: 2
# Processing trip-ID: 586 with dir: 1
# Processing trip-ID: 587 with dir: 2
# Processing trip-ID: 588 with dir: 1
# Processing trip-ID: 589 with dir: 2
# Processing trip-ID: 590 with dir: 1
# Processing trip-ID: 591 with dir: 2
# Processing trip-ID: 592 with dir: 1
# Processing trip-ID: 593 with dir: 2
# Processing trip-ID: 594 with dir: 1
# Processing trip-ID: 595 with dir: 2
# Processing trip-ID: 596 with dir: 1
# Processing trip-ID: 597 with dir: 1
# Processing trip-ID: 598 with dir: 2
# Processing trip-ID: 599 with dir: 1
# Processing trip-ID: 600 with dir: 2
# Processing trip-ID: 601 with dir: 1
# Processing trip-ID: 602 with dir: 2
# Processing trip-ID: 603 with dir: 1
# Processing trip-ID: 604 with dir: 2
# Processing trip-ID: 605 with dir: 1
# Processing trip-ID: 606 with dir: 2
# Processing trip-ID: 607 with dir: 1
# Processing trip-ID: 608 with dir: 2
# Processing trip-ID: 609 with dir: 1
# Processing trip-ID: 610 with dir: 1
# Processing trip-ID: 611 with dir: 2
# Processing trip-ID: 612 with dir: 1
# Processing trip-ID: 613 with dir: 2
# Processing trip-ID: 614 with dir: 1
# Processing trip-ID: 615 with dir: 2
# Processing trip-ID: 616 with dir: 1
# Processing trip-ID: 617 with dir: 2
# Processing trip-ID: 618 with dir: 1
# Processing trip-ID: 619 with dir: 2
# Processing trip-ID: 620 with dir: 1
# Processing trip-ID: 621 with dir: 2
# Processing trip-ID: 622 with dir: 1
# Processing trip-ID: 623 with dir: 2
# Processing trip-ID: 624 with dir: 1
# Processing trip-ID: 625 with dir: 2
# Processing trip-ID: 626 with dir: 1
# Processing trip-ID: 627 with dir: 2
# Processing trip-ID: 628 with dir: 1
# Processing trip-ID: 629 with dir: 2
# Processing trip-ID: 630 with dir: 1
# Processing trip-ID: 631 with dir: 1
# Processing trip-ID: 632 with dir: 2
# Processing trip-ID: 633 with dir: 1
# Processing trip-ID: 634 with dir: 2
# Processing trip-ID: 635 with dir: 1
# Processing trip-ID: 636 with dir: 2
# Processing trip-ID: 637 with dir: 1
# Processing trip-ID: 638 with dir: 2
# Processing trip-ID: 639 with dir: 1
# Processing trip-ID: 640 with dir: 2
# Processing trip-ID: 641 with dir: 1
# Processing trip-ID: 642 with dir: 2
# Processing trip-ID: 643 with dir: 1
# Processing trip-ID: 644 with dir: 2
# Processing trip-ID: 645 with dir: 2
# Processing trip-ID: 646 with dir: 1
# Processing trip-ID: 647 with dir: 2
# Processing trip-ID: 648 with dir: 1
# Processing trip-ID: 649 with dir: 2
# Processing trip-ID: 650 with dir: 1
# Processing trip-ID: 651 with dir: 2
# Processing trip-ID: 652 with dir: 1
# Processing trip-ID: 653 with dir: 2
# Processing trip-ID: 654 with dir: 1
# Processing trip-ID: 655 with dir: 2
# Processing trip-ID: 656 with dir: 1
# Processing trip-ID: 657 with dir: 2
# Processing trip-ID: 658 with dir: 1
# Processing trip-ID: 659 with dir: 2
# Processing trip-ID: 660 with dir: 1
# Processing trip-ID: 661 with dir: 2
# Processing trip-ID: 662 with dir: 1
# Processing trip-ID: 663 with dir: 2
# Processing trip-ID: 664 with dir: 1
# Processing trip-ID: 665 with dir: 2
# Processing trip-ID: 666 with dir: 1
# Processing trip-ID: 667 with dir: 2
# Processing trip-ID: 668 with dir: 1
# Processing trip-ID: 669 with dir: 2
# Processing trip-ID: 670 with dir: 1
# Processing trip-ID: 671 with dir: 2
# Processing trip-ID: 672 with dir: 1
# Processing trip-ID: 673 with dir: 2
# Processing trip-ID: 674 with dir: 1
# Processing trip-ID: 675 with dir: 2
# Processing trip-ID: 676 with dir: 1
# Processing trip-ID: 677 with dir: 2
# Processing trip-ID: 678 with dir: 1
# Processing trip-ID: 679 with dir: 2
# Processing trip-ID: 680 with dir: 1
# Processing trip-ID: 681 with dir: 2
# Processing trip-ID: 682 with dir: 1
# Processing trip-ID: 683 with dir: 2
# Processing trip-ID: 684 with dir: 1
# Processing trip-ID: 685 with dir: 2
# Processing trip-ID: 686 with dir: 1
# Processing trip-ID: 687 with dir: 2
# Processing trip-ID: 688 with dir: 1
# Processing trip-ID: 689 with dir: 2
# Processing trip-ID: 690 with dir: 1
# Processing trip-ID: 691 with dir: 2
# Processing trip-ID: 692 with dir: 1
# Processing trip-ID: 693 with dir: 2
# Processing trip-ID: 694 with dir: 1
# Processing trip-ID: 695 with dir: 2
# Processing trip-ID: 696 with dir: 1
# Processing trip-ID: 697 with dir: 2
# Processing trip-ID: 698 with dir: 1
# Processing trip-ID: 699 with dir: 2
# Processing trip-ID: 700 with dir: 1
# Processing trip-ID: 701 with dir: 2
# Processing trip-ID: 702 with dir: 1
# Processing trip-ID: 703 with dir: 2
# Processing trip-ID: 704 with dir: 1
# Processing trip-ID: 705 with dir: 2
# Processing trip-ID: 706 with dir: 1
# Processing trip-ID: 707 with dir: 2
# Processing trip-ID: 708 with dir: 1
# Processing trip-ID: 709 with dir: 2
# Processing trip-ID: 710 with dir: 1
# Processing trip-ID: 711 with dir: 2
# Processing trip-ID: 712 with dir: 1
# Processing trip-ID: 713 with dir: 2
# Processing trip-ID: 714 with dir: 1
# Processing trip-ID: 715 with dir: 2
# Processing trip-ID: 716 with dir: 1
# Processing trip-ID: 717 with dir: 2
# Processing trip-ID: 718 with dir: 1
# Processing trip-ID: 719 with dir: 2
# Processing trip-ID: 720 with dir: 1
# Processing trip-ID: 721 with dir: 2
# Processing trip-ID: 722 with dir: 1
# Processing trip-ID: 723 with dir: 2
# Processing trip-ID: 724 with dir: 1
# Processing trip-ID: 725 with dir: 2
# Processing trip-ID: 726 with dir: 1
# Processing trip-ID: 727 with dir: 2
# Processing trip-ID: 728 with dir: 1
# Processing trip-ID: 729 with dir: 2
# Processing trip-ID: 730 with dir: 1
# Processing trip-ID: 731 with dir: 2
# Processing trip-ID: 732 with dir: 2
# Processing trip-ID: 733 with dir: 1
# Processing trip-ID: 734 with dir: 2
# Processing trip-ID: 735 with dir: 1
# Processing trip-ID: 736 with dir: 2
# Processing trip-ID: 737 with dir: 1
# Processing trip-ID: 738 with dir: 2
# Processing trip-ID: 739 with dir: 1
# Processing trip-ID: 740 with dir: 2
# Processing trip-ID: 741 with dir: 1
# Processing trip-ID: 742 with dir: 2
# Processing trip-ID: 743 with dir: 1
# Processing trip-ID: 744 with dir: 2
# Processing trip-ID: 745 with dir: 1
# Processing trip-ID: 746 with dir: 2
# Processing trip-ID: 747 with dir: 1
# Processing trip-ID: 748 with dir: 2
# Processing trip-ID: 749 with dir: 1
# Processing trip-ID: 750 with dir: 2
# Processing trip-ID: 751 with dir: 1
# Processing trip-ID: 752 with dir: 2
# Processing trip-ID: 753 with dir: 1
# Processing trip-ID: 754 with dir: 2
# Processing trip-ID: 755 with dir: 1
# Processing trip-ID: 756 with dir: 2
# Processing trip-ID: 757 with dir: 1
# Processing trip-ID: 758 with dir: 2
# Processing trip-ID: 759 with dir: 1
# Processing trip-ID: 760 with dir: 2
# Processing trip-ID: 761 with dir: 1
# Processing trip-ID: 762 with dir: 2
# Processing trip-ID: 763 with dir: 1
# Processing trip-ID: 764 with dir: 2
# Processing trip-ID: 765 with dir: 1
# Processing trip-ID: 766 with dir: 2
# Processing trip-ID: 767 with dir: 1
# Processing trip-ID: 768 with dir: 2
# Processing trip-ID: 769 with dir: 1
# Processing trip-ID: 770 with dir: 2
# Processing trip-ID: 771 with dir: 1
# Processing trip-ID: 772 with dir: 2
# Processing trip-ID: 773 with dir: 1
# Processing trip-ID: 774 with dir: 2
# Processing trip-ID: 775 with dir: 1
# Processing trip-ID: 776 with dir: 2
# Processing trip-ID: 777 with dir: 1
# Processing trip-ID: 778 with dir: 2
# Processing trip-ID: 779 with dir: 1
# Processing trip-ID: 780 with dir: 2
# Processing trip-ID: 781 with dir: 1
# Processing trip-ID: 782 with dir: 2
# Processing trip-ID: 783 with dir: 1
# Processing trip-ID: 784 with dir: 2
# Processing trip-ID: 785 with dir: 1
# Processing trip-ID: 786 with dir: 2
# Processing trip-ID: 787 with dir: 1
# Processing trip-ID: 788 with dir: 2
# Processing trip-ID: 789 with dir: 1
# Processing trip-ID: 790 with dir: 2
# Processing trip-ID: 791 with dir: 1
# Processing trip-ID: 792 with dir: 2
# Processing trip-ID: 793 with dir: 1
# Processing trip-ID: 794 with dir: 2
# Processing trip-ID: 795 with dir: 1
# Processing trip-ID: 796 with dir: 2
# Processing trip-ID: 797 with dir: 1
# Processing trip-ID: 798 with dir: 2
# Processing trip-ID: 799 with dir: 1
# Processing trip-ID: 800 with dir: 2
# Processing trip-ID: 801 with dir: 1
# Processing trip-ID: 802 with dir: 2
# Processing trip-ID: 803 with dir: 1
# Processing trip-ID: 804 with dir: 2
# Processing trip-ID: 805 with dir: 1
# Processing trip-ID: 806 with dir: 2
# Processing trip-ID: 807 with dir: 1
# Processing trip-ID: 808 with dir: 2
# Processing trip-ID: 809 with dir: 1
# Processing trip-ID: 810 with dir: 2
# Processing trip-ID: 811 with dir: 1
# Processing trip-ID: 812 with dir: 2
# Processing trip-ID: 813 with dir: 1
# Processing trip-ID: 814 with dir: 2
# Processing trip-ID: 815 with dir: 1
# Processing trip-ID: 816 with dir: 2
# Processing trip-ID: 817 with dir: 1
# Processing trip-ID: 818 with dir: 2
# Processing trip-ID: 819 with dir: 1
# Processing trip-ID: 820 with dir: 2
# Processing trip-ID: 821 with dir: 1
# Processing trip-ID: 822 with dir: 2
# Processing trip-ID: 823 with dir: 1
# Processing trip-ID: 824 with dir: 2
# Processing trip-ID: 825 with dir: 1
# Processing trip-ID: 826 with dir: 2
# Processing trip-ID: 827 with dir: 1
# Processing trip-ID: 828 with dir: 2
# Processing trip-ID: 829 with dir: 1
# Processing trip-ID: 830 with dir: 2
# Processing trip-ID: 831 with dir: 1
# Processing trip-ID: 832 with dir: 2
# Processing trip-ID: 833 with dir: 1
# Processing trip-ID: 834 with dir: 2
# Processing trip-ID: 835 with dir: 1
# Processing trip-ID: 836 with dir: 2
# Processing trip-ID: 837 with dir: 1
# Processing trip-ID: 838 with dir: 2
# Processing trip-ID: 839 with dir: 1
# Processing trip-ID: 840 with dir: 2
# Processing trip-ID: 841 with dir: 1
# Processing trip-ID: 842 with dir: 2
# Processing trip-ID: 843 with dir: 1
# Processing trip-ID: 844 with dir: 2
# Processing trip-ID: 845 with dir: 1
# Processing trip-ID: 846 with dir: 2
# Processing trip-ID: 847 with dir: 1
# Processing trip-ID: 848 with dir: 2
# Processing trip-ID: 849 with dir: 1
# Processing trip-ID: 850 with dir: 2
# Processing trip-ID: 851 with dir: 1
# Processing trip-ID: 852 with dir: 2
# Processing trip-ID: 853 with dir: 1
# Processing trip-ID: 854 with dir: 2
# Processing trip-ID: 855 with dir: 1
# Processing trip-ID: 856 with dir: 2
# Processing trip-ID: 857 with dir: 1
# Processing trip-ID: 858 with dir: 2
# Processing trip-ID: 859 with dir: 1
# Processing trip-ID: 860 with dir: 2
# Processing trip-ID: 861 with dir: 1
# Processing trip-ID: 862 with dir: 2
# Processing trip-ID: 863 with dir: 1
# Processing trip-ID: 864 with dir: 2
# Processing trip-ID: 865 with dir: 1
# Processing trip-ID: 866 with dir: 2
# Processing trip-ID: 867 with dir: 1
# Processing trip-ID: 868 with dir: 2
# Processing trip-ID: 869 with dir: 1
# Processing trip-ID: 870 with dir: 2
# Processing trip-ID: 871 with dir: 1
# Processing trip-ID: 872 with dir: 2
# Processing trip-ID: 873 with dir: 1
# Processing trip-ID: 874 with dir: 2
# Processing trip-ID: 875 with dir: 1
# Processing trip-ID: 876 with dir: 2
# Processing trip-ID: 877 with dir: 1
# Processing trip-ID: 878 with dir: 2
# Processing trip-ID: 879 with dir: 1
# Processing trip-ID: 880 with dir: 2
# Processing trip-ID: 881 with dir: 1
# Processing trip-ID: 882 with dir: 2
# Processing trip-ID: 883 with dir: 1
# Processing trip-ID: 884 with dir: 2
# Processing trip-ID: 885 with dir: 1
# Processing trip-ID: 886 with dir: 2
# Processing trip-ID: 887 with dir: 1
# Processing trip-ID: 888 with dir: 2
# Processing trip-ID: 889 with dir: 1
# Processing trip-ID: 890 with dir: 2
# Processing trip-ID: 891 with dir: 1
# Processing trip-ID: 892 with dir: 2
# Processing trip-ID: 893 with dir: 1
# Processing trip-ID: 894 with dir: 2
# Processing trip-ID: 895 with dir: 1
# Processing trip-ID: 896 with dir: 2
# Processing trip-ID: 897 with dir: 1
# Processing trip-ID: 898 with dir: 2
# Processing trip-ID: 899 with dir: 1
# Processing trip-ID: 900 with dir: 2
# Processing trip-ID: 901 with dir: 1
# Processing trip-ID: 902 with dir: 2
# Processing trip-ID: 903 with dir: 1
# Processing trip-ID: 904 with dir: 2
# Processing trip-ID: 905 with dir: 1
# Processing trip-ID: 906 with dir: 2
# Processing trip-ID: 907 with dir: 1
# Processing trip-ID: 908 with dir: 2
# Processing trip-ID: 909 with dir: 1
# Processing trip-ID: 910 with dir: 2
# Processing trip-ID: 911 with dir: 1
# Processing trip-ID: 912 with dir: 2
# Processing trip-ID: 913 with dir: 1
# Processing trip-ID: 914 with dir: 2
# Processing trip-ID: 915 with dir: 1
# Processing trip-ID: 916 with dir: 2
# Processing trip-ID: 917 with dir: 1
# Processing trip-ID: 918 with dir: 2
# Processing trip-ID: 919 with dir: 1
# Processing trip-ID: 920 with dir: 2
# Processing trip-ID: 921 with dir: 1
# Processing trip-ID: 922 with dir: 2
# Processing trip-ID: 923 with dir: 1
# Processing trip-ID: 924 with dir: 2
# Processing trip-ID: 925 with dir: 1
# Processing trip-ID: 926 with dir: 2
# Processing trip-ID: 927 with dir: 1
# Processing trip-ID: 928 with dir: 2
# Processing trip-ID: 929 with dir: 1
# Processing trip-ID: 930 with dir: 2
# Processing trip-ID: 931 with dir: 1
# Processing trip-ID: 932 with dir: 2
# Processing trip-ID: 933 with dir: 1
# Processing trip-ID: 934 with dir: 2
# Processing trip-ID: 935 with dir: 1
# Processing trip-ID: 936 with dir: 2
# Processing trip-ID: 937 with dir: 1
# Processing trip-ID: 938 with dir: 2
# Processing trip-ID: 939 with dir: 1
# Processing trip-ID: 940 with dir: 2
# Processing trip-ID: 941 with dir: 1
# Processing trip-ID: 942 with dir: 2
# Processing trip-ID: 943 with dir: 1
# Processing trip-ID: 944 with dir: 2
# Processing trip-ID: 945 with dir: 1
# Processing trip-ID: 946 with dir: 2
# Processing trip-ID: 947 with dir: 1
# Processing trip-ID: 948 with dir: 2
# Processing trip-ID: 949 with dir: 1
# Processing trip-ID: 950 with dir: 2
# Processing trip-ID: 951 with dir: 1
# Processing trip-ID: 952 with dir: 2
# Processing trip-ID: 953 with dir: 1
# Processing trip-ID: 954 with dir: 2
# Processing trip-ID: 955 with dir: 1
# Processing trip-ID: 956 with dir: 2
# Processing trip-ID: 957 with dir: 1
# Processing trip-ID: 958 with dir: 2
# Processing trip-ID: 959 with dir: 1
# Processing trip-ID: 960 with dir: 2
# Processing trip-ID: 961 with dir: 1
# Processing trip-ID: 962 with dir: 2
# Processing trip-ID: 963 with dir: 1
# Processing trip-ID: 964 with dir: 2
# Processing trip-ID: 965 with dir: 1
# Processing trip-ID: 966 with dir: 2
# Processing trip-ID: 967 with dir: 1
# Processing trip-ID: 968 with dir: 2
# Processing trip-ID: 969 with dir: 1
# Processing trip-ID: 970 with dir: 2
# Processing trip-ID: 971 with dir: 1
# Processing trip-ID: 972 with dir: 2
# Processing trip-ID: 973 with dir: 1
# Processing trip-ID: 974 with dir: 2
# Processing trip-ID: 975 with dir: 1
# Processing trip-ID: 976 with dir: 2
# Processing trip-ID: 977 with dir: 1
# Processing trip-ID: 978 with dir: 2
# Processing trip-ID: 979 with dir: 1
# Processing trip-ID: 980 with dir: 2
# Processing trip-ID: 981 with dir: 1
# Processing trip-ID: 982 with dir: 2
# Processing trip-ID: 983 with dir: 1
# Processing trip-ID: 984 with dir: 2
# Processing trip-ID: 985 with dir: 1
# Processing trip-ID: 986 with dir: 2
# Processing trip-ID: 987 with dir: 1
# Processing trip-ID: 988 with dir: 2
# Processing trip-ID: 989 with dir: 1
# Processing trip-ID: 990 with dir: 2
# Processing trip-ID: 991 with dir: 1
# Processing trip-ID: 992 with dir: 2
# Processing trip-ID: 993 with dir: 1
# Processing trip-ID: 994 with dir: 2
# Processing trip-ID: 995 with dir: 1
# Processing trip-ID: 996 with dir: 2
# Processing trip-ID: 997 with dir: 1
# Processing trip-ID: 998 with dir: 2
# Processing trip-ID: 999 with dir: 1
# Processing trip-ID: 1000 with dir: 2
# Processing trip-ID: 1001 with dir: 1
# Processing trip-ID: 1002 with dir: 2
# Processing trip-ID: 1003 with dir: 1
# Processing trip-ID: 1004 with dir: 2
# Processing trip-ID: 1005 with dir: 1
# Processing trip-ID: 1006 with dir: 2
# Processing trip-ID: 1007 with dir: 1
# Processing trip-ID: 1008 with dir: 2
# Processing trip-ID: 1009 with dir: 1
# Processing trip-ID: 1010 with dir: 2
# Processing trip-ID: 1011 with dir: 1
# Processing trip-ID: 1012 with dir: 2
# Processing trip-ID: 1013 with dir: 1
# Processing trip-ID: 1014 with dir: 2
# Processing trip-ID: 1015 with dir: 1
# Processing trip-ID: 1016 with dir: 2
# Processing trip-ID: 1017 with dir: 1
# Processing trip-ID: 1018 with dir: 2
# Processing trip-ID: 1019 with dir: 1
# Processing trip-ID: 1020 with dir: 2
# Processing trip-ID: 1021 with dir: 1
# Processing trip-ID: 1022 with dir: 2
# Processing trip-ID: 1023 with dir: 1
# Processing trip-ID: 1024 with dir: 2
# Processing trip-ID: 1025 with dir: 1
# Processing trip-ID: 1026 with dir: 2
# Processing trip-ID: 1027 with dir: 1
# Processing trip-ID: 1028 with dir: 2
# Processing trip-ID: 1029 with dir: 1
# Processing trip-ID: 1030 with dir: 2
# Processing trip-ID: 1031 with dir: 1
# Processing trip-ID: 1032 with dir: 2
# Processing trip-ID: 1033 with dir: 1
# Processing trip-ID: 1034 with dir: 2
# Processing trip-ID: 1035 with dir: 1
# Processing trip-ID: 1036 with dir: 2
# Processing trip-ID: 1037 with dir: 1
# Processing trip-ID: 1038 with dir: 2
# Processing trip-ID: 1039 with dir: 1
# Processing trip-ID: 1040 with dir: 2
# Processing trip-ID: 1041 with dir: 1
# Processing trip-ID: 1042 with dir: 2
# Processing trip-ID: 1043 with dir: 1
# Processing trip-ID: 1044 with dir: 2
# Processing trip-ID: 1045 with dir: 1
# Processing trip-ID: 1046 with dir: 2
# Processing trip-ID: 1047 with dir: 1
# Processing trip-ID: 1048 with dir: 2
# Processing trip-ID: 1049 with dir: 1
# Processing trip-ID: 1050 with dir: 2
# Processing trip-ID: 1051 with dir: 1
# Processing trip-ID: 1052 with dir: 2
# Processing trip-ID: 1053 with dir: 1
# Processing trip-ID: 1054 with dir: 2
# Processing trip-ID: 1055 with dir: 1
# Processing trip-ID: 1056 with dir: 2
# Processing trip-ID: 1057 with dir: 1
# Processing trip-ID: 1058 with dir: 2
# Processing trip-ID: 1059 with dir: 1
# Processing trip-ID: 1060 with dir: 2
# Processing trip-ID: 1061 with dir: 1
# Processing trip-ID: 1062 with dir: 2
# Processing trip-ID: 1063 with dir: 1
# Processing trip-ID: 1064 with dir: 2
# Processing trip-ID: 1065 with dir: 1
# Processing trip-ID: 1066 with dir: 2
# Processing trip-ID: 1067 with dir: 1
# Processing trip-ID: 1068 with dir: 2
# Processing trip-ID: 1069 with dir: 1
# Processing trip-ID: 1070 with dir: 2
# Processing trip-ID: 1071 with dir: 1
# Processing trip-ID: 1072 with dir: 2
# Processing trip-ID: 1073 with dir: 1
# Processing trip-ID: 1074 with dir: 2
# Processing trip-ID: 1075 with dir: 1
# Processing trip-ID: 1076 with dir: 2
# Processing trip-ID: 1077 with dir: 1
# Processing trip-ID: 1078 with dir: 2
# Processing trip-ID: 1079 with dir: 1
# Processing trip-ID: 1080 with dir: 2
# Processing trip-ID: 1081 with dir: 1
# Processing trip-ID: 1082 with dir: 2
# Processing trip-ID: 1083 with dir: 1
# Processing trip-ID: 1084 with dir: 2
# Processing trip-ID: 1085 with dir: 1
# Processing trip-ID: 1086 with dir: 2
# Processing trip-ID: 1087 with dir: 1
# Processing trip-ID: 1088 with dir: 2
# Processing trip-ID: 1089 with dir: 1
# Processing trip-ID: 1090 with dir: 2
# Processing trip-ID: 1091 with dir: 1
# Processing trip-ID: 1092 with dir: 2
# Processing trip-ID: 1093 with dir: 1
# Processing trip-ID: 1094 with dir: 2
# Processing trip-ID: 1095 with dir: 1
# Processing trip-ID: 1096 with dir: 2
# Processing trip-ID: 1097 with dir: 1
# Processing trip-ID: 1098 with dir: 2
# Processing trip-ID: 1099 with dir: 1
# Processing trip-ID: 1100 with dir: 2
# Processing trip-ID: 1101 with dir: 1
# Processing trip-ID: 1102 with dir: 2
# Processing trip-ID: 1103 with dir: 1
# Processing trip-ID: 1104 with dir: 2
# Processing trip-ID: 1105 with dir: 1
# Processing trip-ID: 1106 with dir: 2
# Processing trip-ID: 1107 with dir: 1
# Processing trip-ID: 1108 with dir: 2
# Processing trip-ID: 1109 with dir: 2
# Processing trip-ID: 1110 with dir: 1
# Processing trip-ID: 1111 with dir: 2
# Processing trip-ID: 1112 with dir: 1
# Processing trip-ID: 1113 with dir: 2
# Processing trip-ID: 1114 with dir: 1
# Processing trip-ID: 1115 with dir: 2
# Processing trip-ID: 1116 with dir: 1
# Processing trip-ID: 1117 with dir: 2
# Processing trip-ID: 1118 with dir: 1
# Processing trip-ID: 1119 with dir: 2
# Processing trip-ID: 1120 with dir: 1
# Processing trip-ID: 1121 with dir: 2
# Processing trip-ID: 1122 with dir: 1
# Processing trip-ID: 1123 with dir: 2
# Processing trip-ID: 1124 with dir: 1
# Processing trip-ID: 1125 with dir: 2
# Processing trip-ID: 1126 with dir: 1
# Processing trip-ID: 1127 with dir: 2
# Processing trip-ID: 1128 with dir: 1
# Processing trip-ID: 1129 with dir: 2
# Processing trip-ID: 1130 with dir: 1
# Processing trip-ID: 1131 with dir: 2
# Processing trip-ID: 1132 with dir: 1
# Processing trip-ID: 1133 with dir: 2
# Processing trip-ID: 1134 with dir: 1
# Processing trip-ID: 1135 with dir: 2
# Processing trip-ID: 1136 with dir: 1
# Processing trip-ID: 1137 with dir: 2
# Processing trip-ID: 1138 with dir: 1
# Processing trip-ID: 1139 with dir: 2
# Processing trip-ID: 1140 with dir: 1
# Processing trip-ID: 1141 with dir: 2
# Processing trip-ID: 1142 with dir: 1
# Processing trip-ID: 1143 with dir: 2
# Processing trip-ID: 1144 with dir: 1
# Processing trip-ID: 1145 with dir: 2
# Processing trip-ID: 1146 with dir: 1
# Processing trip-ID: 1147 with dir: 2
# Processing trip-ID: 1148 with dir: 1
# Processing trip-ID: 1149 with dir: 2
# Processing trip-ID: 1150 with dir: 1
# Processing trip-ID: 1151 with dir: 2
# Processing trip-ID: 1152 with dir: 1
# Processing trip-ID: 1153 with dir: 2
# Processing trip-ID: 1154 with dir: 1
# Processing trip-ID: 1155 with dir: 2
# Processing trip-ID: 1156 with dir: 1
# Processing trip-ID: 1157 with dir: 2
# Processing trip-ID: 1158 with dir: 1
# Processing trip-ID: 1159 with dir: 2
# Processing trip-ID: 1160 with dir: 1
# Processing trip-ID: 1161 with dir: 2
# Processing trip-ID: 1162 with dir: 1
# Processing trip-ID: 1163 with dir: 2
# Processing trip-ID: 1164 with dir: 1
# Processing trip-ID: 1165 with dir: 2
# Processing trip-ID: 1166 with dir: 1
# Processing trip-ID: 1167 with dir: 2
# Processing trip-ID: 1168 with dir: 1
# Processing trip-ID: 1169 with dir: 2
# Processing trip-ID: 1170 with dir: 1
# Processing trip-ID: 1171 with dir: 2
# Processing trip-ID: 1172 with dir: 2
# Processing trip-ID: 1173 with dir: 1
# Processing trip-ID: 1174 with dir: 2
# Processing trip-ID: 1175 with dir: 1
# Processing trip-ID: 1176 with dir: 2
# Processing trip-ID: 1177 with dir: 1
# Processing trip-ID: 1178 with dir: 2
# Processing trip-ID: 1179 with dir: 1
# Processing trip-ID: 1180 with dir: 2
# Processing trip-ID: 1181 with dir: 1
# Processing trip-ID: 1182 with dir: 2
# Processing trip-ID: 1183 with dir: 1
# Processing trip-ID: 1184 with dir: 2
# Processing trip-ID: 1185 with dir: 1
# Processing trip-ID: 1186 with dir: 2
# Processing trip-ID: 1187 with dir: 1
# Processing trip-ID: 1188 with dir: 2
# Processing trip-ID: 1189 with dir: 1
# Processing trip-ID: 1190 with dir: 2
# Processing trip-ID: 1191 with dir: 1
# Processing trip-ID: 1192 with dir: 2
# Processing trip-ID: 1193 with dir: 1
# Processing trip-ID: 1194 with dir: 2
# Processing trip-ID: 1195 with dir: 1
# Processing trip-ID: 1196 with dir: 2
# Processing trip-ID: 1197 with dir: 1
# Processing trip-ID: 1198 with dir: 2
# Processing trip-ID: 1199 with dir: 1
# Processing trip-ID: 1200 with dir: 2
# Processing trip-ID: 1201 with dir: 1
# Processing trip-ID: 1202 with dir: 2
# Processing trip-ID: 1203 with dir: 1
# Processing trip-ID: 1204 with dir: 2
# Processing trip-ID: 1205 with dir: 1
# Processing trip-ID: 1206 with dir: 2
# Processing trip-ID: 1207 with dir: 1
# Processing trip-ID: 1208 with dir: 2
# Processing trip-ID: 1209 with dir: 1
# Processing trip-ID: 1210 with dir: 2
# Processing trip-ID: 1211 with dir: 1
# Processing trip-ID: 1212 with dir: 2
# Processing trip-ID: 1213 with dir: 1
# Processing trip-ID: 1214 with dir: 2
# Processing trip-ID: 1215 with dir: 1
# Processing trip-ID: 1216 with dir: 2
# Processing trip-ID: 1217 with dir: 1
# Processing trip-ID: 1218 with dir: 2
# Processing trip-ID: 1219 with dir: 1
# Processing trip-ID: 1220 with dir: 2
# Processing trip-ID: 1221 with dir: 1
# Processing trip-ID: 1222 with dir: 2
# Processing trip-ID: 1223 with dir: 1
# Processing trip-ID: 1224 with dir: 2
# Processing trip-ID: 1225 with dir: 1
# Processing trip-ID: 1226 with dir: 2
# Processing trip-ID: 1227 with dir: 1
# Processing trip-ID: 1228 with dir: 2
# Processing trip-ID: 1229 with dir: 1
# Processing trip-ID: 1230 with dir: 2
# Processing trip-ID: 1231 with dir: 1
# Processing trip-ID: 1232 with dir: 2
# Processing trip-ID: 1233 with dir: 1
# Processing trip-ID: 1234 with dir: 2
# Processing trip-ID: 1235 with dir: 1
# Processing trip-ID: 1236 with dir: 2
# Processing trip-ID: 1237 with dir: 1
# Processing trip-ID: 1238 with dir: 2
# Processing trip-ID: 1239 with dir: 1
# Processing trip-ID: 1240 with dir: 2
# Processing trip-ID: 1241 with dir: 1
# Processing trip-ID: 1242 with dir: 2
# Processing trip-ID: 1243 with dir: 1
# Processing trip-ID: 1244 with dir: 2
# Processing trip-ID: 1245 with dir: 1
# Processing trip-ID: 1246 with dir: 2
# Processing trip-ID: 1247 with dir: 1
# Processing trip-ID: 1248 with dir: 2
# Processing trip-ID: 1249 with dir: 1
# Processing trip-ID: 1250 with dir: 2
# Processing trip-ID: 1251 with dir: 1
# Processing trip-ID: 1252 with dir: 2
# Processing trip-ID: 1253 with dir: 1
# Processing trip-ID: 1254 with dir: 2
# Processing trip-ID: 1255 with dir: 1
# Processing trip-ID: 1256 with dir: 2
# Processing trip-ID: 1257 with dir: 1
# Processing trip-ID: 1258 with dir: 2
# Processing trip-ID: 1259 with dir: 1
# Processing trip-ID: 1260 with dir: 2
# Processing trip-ID: 1261 with dir: 1
# Processing trip-ID: 1262 with dir: 2
# Processing trip-ID: 1263 with dir: 1
# Processing trip-ID: 1264 with dir: 2
# Processing trip-ID: 1265 with dir: 1
# Processing trip-ID: 1266 with dir: 2
# Processing trip-ID: 1267 with dir: 1
# Processing trip-ID: 1268 with dir: 2
# Processing trip-ID: 1269 with dir: 1
# Processing trip-ID: 1270 with dir: 2
# Processing trip-ID: 1271 with dir: 2
# Processing trip-ID: 1272 with dir: 2
# Processing trip-ID: 1273 with dir: 1
# Processing trip-ID: 1274 with dir: 1
# Processing trip-ID: 1275 with dir: 2
# Processing trip-ID: 1276 with dir: 2
# Processing trip-ID: 1277 with dir: 1
# Processing trip-ID: 1278 with dir: 2
# Processing trip-ID: 1279 with dir: 1
# Processing trip-ID: 1280 with dir: 2
# Processing trip-ID: 1281 with dir: 2
# Processing trip-ID: 1282 with dir: 1
# Processing trip-ID: 1283 with dir: 2
# Processing trip-ID: 1284 with dir: 1
# Processing trip-ID: 1285 with dir: 2
# Processing trip-ID: 1286 with dir: 1
# Processing trip-ID: 1287 with dir: 2
# Processing trip-ID: 1288 with dir: 1
# Processing trip-ID: 1289 with dir: 2
# Processing trip-ID: 1290 with dir: 2
# Processing trip-ID: 1291 with dir: 2
# Processing trip-ID: 1292 with dir: 1
# Processing trip-ID: 1293 with dir: 2
# Processing trip-ID: 1294 with dir: 1
# Processing trip-ID: 1295 with dir: 1
# Processing trip-ID: 1296 with dir: 2
# Processing trip-ID: 1297 with dir: 1
# Processing trip-ID: 1298 with dir: 2
# Processing trip-ID: 1299 with dir: 1
# Processing trip-ID: 1300 with dir: 2
# Processing trip-ID: 1301 with dir: 1
# Processing trip-ID: 1302 with dir: 1
# Processing trip-ID: 1303 with dir: 2
# Processing trip-ID: 1304 with dir: 1
# Processing trip-ID: 1305 with dir: 2
# Processing trip-ID: 1306 with dir: 1
# Processing trip-ID: 1307 with dir: 2
# Processing trip-ID: 1308 with dir: 1
# Processing trip-ID: 1309 with dir: 2
# Processing trip-ID: 1310 with dir: 2
# Processing trip-ID: 1311 with dir: 2
# Processing trip-ID: 1312 with dir: 1
# Processing trip-ID: 1313 with dir: 1
# Processing trip-ID: 1314 with dir: 2
# Processing trip-ID: 1315 with dir: 1
# Processing trip-ID: 1316 with dir: 2
# Processing trip-ID: 1317 with dir: 1
# Processing trip-ID: 1318 with dir: 2
# Processing trip-ID: 1319 with dir: 1
# Processing trip-ID: 1320 with dir: 1
# Processing trip-ID: 1321 with dir: 2
# Processing trip-ID: 1322 with dir: 1
# Processing trip-ID: 1323 with dir: 2
# Processing trip-ID: 1324 with dir: 1
# Processing trip-ID: 1325 with dir: 2
# Processing trip-ID: 1326 with dir: 1
# Processing trip-ID: 1327 with dir: 2
# Processing trip-ID: 1328 with dir: 1
# Processing trip-ID: 1329 with dir: 2
# Processing trip-ID: 1330 with dir: 1
# Processing trip-ID: 1331 with dir: 2
# Processing trip-ID: 1332 with dir: 1
# Processing trip-ID: 1333 with dir: 2
# Processing trip-ID: 1334 with dir: 1
# Processing trip-ID: 1335 with dir: 2
# Processing trip-ID: 1336 with dir: 1
# Processing trip-ID: 1337 with dir: 2
# Processing trip-ID: 1338 with dir: 1
# Processing trip-ID: 1339 with dir: 2
# Processing trip-ID: 1340 with dir: 2
# Processing trip-ID: 1341 with dir: 2
# Processing trip-ID: 1342 with dir: 1
# Processing trip-ID: 1343 with dir: 2
# Processing trip-ID: 1344 with dir: 1
# Processing trip-ID: 1345 with dir: 2
# Processing trip-ID: 1346 with dir: 1
# Processing trip-ID: 1347 with dir: 2
# Processing trip-ID: 1348 with dir: 1
# Processing trip-ID: 1349 with dir: 2
# Processing trip-ID: 1350 with dir: 1
# Processing trip-ID: 1351 with dir: 2
# Processing trip-ID: 1352 with dir: 1
# Processing trip-ID: 1353 with dir: 2
# Processing trip-ID: 1354 with dir: 2
# Processing trip-ID: 1355 with dir: 1
# Processing trip-ID: 1356 with dir: 2
# Processing trip-ID: 1357 with dir: 1
# Processing trip-ID: 1358 with dir: 2
# Processing trip-ID: 1359 with dir: 1
# Processing trip-ID: 1360 with dir: 2
# Processing trip-ID: 1361 with dir: 1
# Processing trip-ID: 1362 with dir: 2
# Processing trip-ID: 1363 with dir: 1
# Processing trip-ID: 1364 with dir: 2
# Processing trip-ID: 1365 with dir: 1
# Processing trip-ID: 1366 with dir: 2
# Processing trip-ID: 1367 with dir: 2
# Processing trip-ID: 1368 with dir: 1
# Processing trip-ID: 1369 with dir: 2
# Processing trip-ID: 1370 with dir: 1
# Processing trip-ID: 1371 with dir: 2
# Processing trip-ID: 1372 with dir: 2
# Processing trip-ID: 1373 with dir: 2
# Processing trip-ID: 1374 with dir: 1
# Processing trip-ID: 1375 with dir: 2
# Processing trip-ID: 1376 with dir: 1
# Processing trip-ID: 1377 with dir: 2
# Processing trip-ID: 1378 with dir: 1
# Processing trip-ID: 1379 with dir: 2
# Processing trip-ID: 1380 with dir: 1
# Processing trip-ID: 1381 with dir: 2
# Processing trip-ID: 1382 with dir: 1
# Processing trip-ID: 1383 with dir: 2
# Processing trip-ID: 1384 with dir: 1
# Processing trip-ID: 1385 with dir: 2
# Processing trip-ID: 1386 with dir: 1
# Processing trip-ID: 1387 with dir: 2
# Processing trip-ID: 1388 with dir: 1
# Processing trip-ID: 1389 with dir: 2
# Processing trip-ID: 1390 with dir: 1
# Processing trip-ID: 1391 with dir: 2
# Processing trip-ID: 1392 with dir: 1
# Processing trip-ID: 1393 with dir: 2
# Processing trip-ID: 1394 with dir: 1
# Processing trip-ID: 1395 with dir: 2
# Processing trip-ID: 1396 with dir: 1
# Processing trip-ID: 1397 with dir: 2
# Processing trip-ID: 1398 with dir: 1
# Processing trip-ID: 1399 with dir: 2
# Processing trip-ID: 1400 with dir: 1
# Processing trip-ID: 1401 with dir: 2
# Processing trip-ID: 1402 with dir: 1
# Processing trip-ID: 1403 with dir: 2
# Processing trip-ID: 1404 with dir: 1
# Processing trip-ID: 1405 with dir: 2
# Processing trip-ID: 1406 with dir: 1
# Processing trip-ID: 1407 with dir: 2
# Processing trip-ID: 1408 with dir: 1
# Processing trip-ID: 1409 with dir: 2
# Processing trip-ID: 1410 with dir: 1
# Processing trip-ID: 1411 with dir: 2
# Processing trip-ID: 1412 with dir: 1
# Processing trip-ID: 1413 with dir: 2
# Processing trip-ID: 1414 with dir: 1
# Processing trip-ID: 1415 with dir: 2
# Processing trip-ID: 1416 with dir: 1
# Processing trip-ID: 1417 with dir: 2
# Processing trip-ID: 1418 with dir: 1
# Processing trip-ID: 1419 with dir: 2
# Processing trip-ID: 1420 with dir: 1
# Processing trip-ID: 1421 with dir: 2
# Processing trip-ID: 1422 with dir: 1
# Processing trip-ID: 1423 with dir: 2
# Processing trip-ID: 1424 with dir: 1
# Processing trip-ID: 1425 with dir: 2
# Processing trip-ID: 1426 with dir: 1
# Processing trip-ID: 1427 with dir: 2
# Processing trip-ID: 1428 with dir: 1
# Processing trip-ID: 1429 with dir: 2
# Processing trip-ID: 1430 with dir: 1
# Processing trip-ID: 1431 with dir: 2
# Processing trip-ID: 1432 with dir: 1
# Processing trip-ID: 1433 with dir: 2
# Processing trip-ID: 1434 with dir: 1
# Processing trip-ID: 1435 with dir: 2
# Processing trip-ID: 1436 with dir: 1
# Processing trip-ID: 1437 with dir: 2
# Processing trip-ID: 1438 with dir: 1
# Processing trip-ID: 1439 with dir: 2
# Processing trip-ID: 1440 with dir: 1
# Processing trip-ID: 1441 with dir: 2
# Processing trip-ID: 1442 with dir: 1
# Processing trip-ID: 1443 with dir: 2
# Processing trip-ID: 1444 with dir: 1
# Processing trip-ID: 1445 with dir: 2
# Processing trip-ID: 1446 with dir: 1
# Processing trip-ID: 1447 with dir: 2
# Processing trip-ID: 1448 with dir: 1
# Processing trip-ID: 1449 with dir: 2
# Processing trip-ID: 1450 with dir: 1
# Processing trip-ID: 1451 with dir: 2
# Processing trip-ID: 1452 with dir: 1
# Processing trip-ID: 1453 with dir: 2
# Processing trip-ID: 1454 with dir: 1
# Processing trip-ID: 1455 with dir: 2
# Processing trip-ID: 1456 with dir: 1
# Processing trip-ID: 1457 with dir: 2
# Processing trip-ID: 1458 with dir: 1
# Processing trip-ID: 1459 with dir: 2
# Processing trip-ID: 1460 with dir: 1
# Processing trip-ID: 1461 with dir: 2
# Processing trip-ID: 1462 with dir: 1
# Processing trip-ID: 1463 with dir: 2
# Processing trip-ID: 1464 with dir: 1
# Processing trip-ID: 1465 with dir: 2
# Processing trip-ID: 1466 with dir: 1
# Processing trip-ID: 1467 with dir: 2
# Processing trip-ID: 1468 with dir: 1
# Processing trip-ID: 1469 with dir: 2
# Processing trip-ID: 1470 with dir: 1
# Processing trip-ID: 1471 with dir: 2
# Processing trip-ID: 1472 with dir: 1
# Processing trip-ID: 1473 with dir: 2
# Processing trip-ID: 1474 with dir: 1
# Processing trip-ID: 1475 with dir: 2
# Processing trip-ID: 1476 with dir: 1
# Processing trip-ID: 1477 with dir: 2
# Processing trip-ID: 1478 with dir: 1
# Processing trip-ID: 1479 with dir: 2
# Processing trip-ID: 1480 with dir: 1
# Processing trip-ID: 1481 with dir: 2
# Processing trip-ID: 1482 with dir: 1
# Processing trip-ID: 1483 with dir: 2
# Processing trip-ID: 1484 with dir: 1
# Processing trip-ID: 1485 with dir: 2
# Processing trip-ID: 1486 with dir: 1
# Processing trip-ID: 1487 with dir: 2
# Processing trip-ID: 1488 with dir: 1
# Processing trip-ID: 1489 with dir: 2
# Processing trip-ID: 1490 with dir: 1
# Processing trip-ID: 1491 with dir: 2
# Processing trip-ID: 1492 with dir: 1
# Processing trip-ID: 1493 with dir: 2
# Processing trip-ID: 1494 with dir: 1
# Processing trip-ID: 1495 with dir: 2
# Processing trip-ID: 1496 with dir: 1
# Processing trip-ID: 1497 with dir: 2
# Processing trip-ID: 1498 with dir: 1
# Processing trip-ID: 1499 with dir: 2
# Processing trip-ID: 1500 with dir: 1
# Processing trip-ID: 1501 with dir: 2
# Processing trip-ID: 1502 with dir: 1
# Processing trip-ID: 1503 with dir: 2
# Processing trip-ID: 1504 with dir: 1
# Processing trip-ID: 1505 with dir: 2
# Processing trip-ID: 1506 with dir: 1
# Processing trip-ID: 1507 with dir: 2
# Processing trip-ID: 1508 with dir: 1
# Processing trip-ID: 1509 with dir: 2
# Processing trip-ID: 1510 with dir: 1
# Processing trip-ID: 1511 with dir: 2
# Processing trip-ID: 1512 with dir: 1
# Processing trip-ID: 1513 with dir: 2
# Processing trip-ID: 1514 with dir: 1
# Processing trip-ID: 1515 with dir: 2
# Processing trip-ID: 1516 with dir: 1
# Processing trip-ID: 1517 with dir: 2
# Processing trip-ID: 1518 with dir: 1
# Processing trip-ID: 1519 with dir: 2
# Processing trip-ID: 1520 with dir: 1
# Processing trip-ID: 1521 with dir: 2
# Processing trip-ID: 1522 with dir: 1
# Processing trip-ID: 1523 with dir: 2
# Processing trip-ID: 1524 with dir: 1
# Processing trip-ID: 1525 with dir: 2
# Processing trip-ID: 1526 with dir: 1
# Processing trip-ID: 1527 with dir: 2
# Processing trip-ID: 1528 with dir: 1
# Processing trip-ID: 1529 with dir: 2
# Processing trip-ID: 1530 with dir: 1
# Processing trip-ID: 1531 with dir: 2
# Processing trip-ID: 1532 with dir: 1
# Processing trip-ID: 1533 with dir: 2
# Processing trip-ID: 1534 with dir: 1
# Processing trip-ID: 1535 with dir: 2
# Processing trip-ID: 1536 with dir: 1
# Processing trip-ID: 1537 with dir: 2
# Processing trip-ID: 1538 with dir: 1
# Processing trip-ID: 1539 with dir: 2
# Processing trip-ID: 1540 with dir: 1
# Processing trip-ID: 1541 with dir: 2
# Processing trip-ID: 1542 with dir: 1
# Processing trip-ID: 1543 with dir: 2
# Processing trip-ID: 1544 with dir: 1
# Processing trip-ID: 1545 with dir: 2
# Processing trip-ID: 1546 with dir: 1
# Processing trip-ID: 1547 with dir: 2
# Processing trip-ID: 1548 with dir: 1
# Processing trip-ID: 1549 with dir: 2
# Processing trip-ID: 1550 with dir: 1
# Processing trip-ID: 1551 with dir: 2
# Processing trip-ID: 1552 with dir: 1
# Processing trip-ID: 1553 with dir: 2
# Processing trip-ID: 1554 with dir: 1
# Processing trip-ID: 1555 with dir: 2
# Processing trip-ID: 1556 with dir: 1
# Processing trip-ID: 1557 with dir: 2
# Processing trip-ID: 1558 with dir: 1
# Processing trip-ID: 1559 with dir: 2
# Processing trip-ID: 1560 with dir: 1
# Processing trip-ID: 1561 with dir: 2
# Processing trip-ID: 1562 with dir: 1
# Processing trip-ID: 1563 with dir: 2
# Processing trip-ID: 1564 with dir: 1
# Processing trip-ID: 1565 with dir: 2
# Processing trip-ID: 1566 with dir: 1
# Processing trip-ID: 1567 with dir: 2
# Processing trip-ID: 1568 with dir: 1
# Processing trip-ID: 1569 with dir: 2
# Processing trip-ID: 1570 with dir: 1
# Processing trip-ID: 1571 with dir: 2
# Processing trip-ID: 1572 with dir: 1
# Processing trip-ID: 1573 with dir: 2
# Processing trip-ID: 1574 with dir: 1
# Processing trip-ID: 1575 with dir: 2
# Processing trip-ID: 1576 with dir: 1
# Processing trip-ID: 1577 with dir: 2
# Processing trip-ID: 1578 with dir: 1
# Processing trip-ID: 1579 with dir: 2
# Processing trip-ID: 1580 with dir: 1
# Processing trip-ID: 1581 with dir: 2
# Processing trip-ID: 1582 with dir: 1
# Processing trip-ID: 1583 with dir: 2
# Processing trip-ID: 1584 with dir: 1
# Processing trip-ID: 1585 with dir: 2
# Processing trip-ID: 1586 with dir: 1
# Processing trip-ID: 1587 with dir: 2
# Processing trip-ID: 1588 with dir: 1
# Processing trip-ID: 1589 with dir: 2
# Processing trip-ID: 1590 with dir: 1
# Processing trip-ID: 1591 with dir: 2
# Processing trip-ID: 1592 with dir: 1
# Processing trip-ID: 1593 with dir: 2
# Processing trip-ID: 1594 with dir: 1
# Processing trip-ID: 1595 with dir: 2
# Processing trip-ID: 1596 with dir: 2
# Processing trip-ID: 1597 with dir: 1
# Processing trip-ID: 1598 with dir: 2
# Processing trip-ID: 1599 with dir: 1
# Processing trip-ID: 1600 with dir: 2
# Processing trip-ID: 1601 with dir: 1
# Processing trip-ID: 1602 with dir: 2
# Processing trip-ID: 1603 with dir: 1
# Processing trip-ID: 1604 with dir: 2
# Processing trip-ID: 1605 with dir: 1
# Processing trip-ID: 1606 with dir: 2
# Processing trip-ID: 1607 with dir: 1
# Processing trip-ID: 1608 with dir: 2
# Processing trip-ID: 1609 with dir: 2
# Processing trip-ID: 1610 with dir: 1
# Processing trip-ID: 1611 with dir: 2
# Processing trip-ID: 1612 with dir: 1
# Processing trip-ID: 1613 with dir: 2
# Processing trip-ID: 1614 with dir: 1
# Processing trip-ID: 1615 with dir: 2
# Processing trip-ID: 1616 with dir: 1
# Processing trip-ID: 1617 with dir: 2
# Processing trip-ID: 1618 with dir: 1
# Processing trip-ID: 1619 with dir: 2
# Processing trip-ID: 1620 with dir: 1
# Processing trip-ID: 1621 with dir: 2
# Processing trip-ID: 1622 with dir: 2
# Processing trip-ID: 1623 with dir: 1
# Processing trip-ID: 1624 with dir: 2
# Processing trip-ID: 1625 with dir: 1
# Processing trip-ID: 1626 with dir: 2
# Processing trip-ID: 1627 with dir: 1
# Processing trip-ID: 1628 with dir: 2
# Processing trip-ID: 1629 with dir: 1
# Processing trip-ID: 1630 with dir: 2
# Processing trip-ID: 1631 with dir: 1
# Processing trip-ID: 1632 with dir: 2
# Processing trip-ID: 1633 with dir: 1
# Processing trip-ID: 1634 with dir: 2
# Processing trip-ID: 1635 with dir: 2
# Processing trip-ID: 1636 with dir: 1
# Processing trip-ID: 1637 with dir: 2
# Processing trip-ID: 1638 with dir: 1
# Processing trip-ID: 1639 with dir: 2
# Processing trip-ID: 1640 with dir: 1
# Processing trip-ID: 1641 with dir: 2
# Processing trip-ID: 1642 with dir: 1
# Processing trip-ID: 1643 with dir: 2
# Processing trip-ID: 1644 with dir: 1
# Processing trip-ID: 1645 with dir: 2
# Processing trip-ID: 1646 with dir: 1
# Processing trip-ID: 1647 with dir: 2
# Processing trip-ID: 1648 with dir: 1
# Processing trip-ID: 1649 with dir: 2
# Processing trip-ID: 1650 with dir: 1
# Processing trip-ID: 1651 with dir: 2
# Processing trip-ID: 1652 with dir: 1
# Processing trip-ID: 1653 with dir: 2
# Processing trip-ID: 1654 with dir: 1
# Processing trip-ID: 1655 with dir: 2
# Processing trip-ID: 1656 with dir: 1
# Processing trip-ID: 1657 with dir: 2
# Processing trip-ID: 1658 with dir: 2
# Processing trip-ID: 1659 with dir: 1
# Processing trip-ID: 1660 with dir: 2
# Processing trip-ID: 1661 with dir: 1
# Processing trip-ID: 1662 with dir: 2
# Processing trip-ID: 1663 with dir: 1
# Processing trip-ID: 1664 with dir: 2
# Processing trip-ID: 1665 with dir: 2
# Processing trip-ID: 1666 with dir: 1
# Processing trip-ID: 1667 with dir: 2
# Processing trip-ID: 1668 with dir: 1
# Processing trip-ID: 1669 with dir: 2
# Processing trip-ID: 1670 with dir: 1
# Processing trip-ID: 1671 with dir: 2
# Processing trip-ID: 1672 with dir: 1
# Processing trip-ID: 1673 with dir: 2
# Processing trip-ID: 1674 with dir: 1
# Processing trip-ID: 1675 with dir: 2
# Processing trip-ID: 1676 with dir: 1
# Processing trip-ID: 1677 with dir: 2
# Processing trip-ID: 1678 with dir: 1
# Processing trip-ID: 1679 with dir: 2
# Processing trip-ID: 1680 with dir: 1
# Processing trip-ID: 1681 with dir: 2
# Processing trip-ID: 1682 with dir: 1
# Processing trip-ID: 1683 with dir: 2
# Processing trip-ID: 1684 with dir: 2
# Processing trip-ID: 1685 with dir: 1
# Processing trip-ID: 1686 with dir: 2
# Processing trip-ID: 1687 with dir: 1
# Processing trip-ID: 1688 with dir: 2
# Processing trip-ID: 1689 with dir: 1
# Processing trip-ID: 1690 with dir: 2
# Processing trip-ID: 1691 with dir: 1
# Processing trip-ID: 1692 with dir: 2
# Processing trip-ID: 1693 with dir: 1
# Processing trip-ID: 1694 with dir: 2
# Processing trip-ID: 1695 with dir: 1
# Processing trip-ID: 1696 with dir: 2
# Processing trip-ID: 1697 with dir: 1
# Processing trip-ID: 1698 with dir: 2
# Processing trip-ID: 1699 with dir: 1
# Processing trip-ID: 1700 with dir: 2
# Processing trip-ID: 1701 with dir: 1
# Processing trip-ID: 1702 with dir: 2
# Processing trip-ID: 1703 with dir: 1
# Processing trip-ID: 1704 with dir: 2
# Processing trip-ID: 1705 with dir: 1
# Processing trip-ID: 1706 with dir: 2

# %%
result_df[result_df['trip_id']>1706]
# Out:
#                id  deviceid           devicetime  latitude  longitude  \
# 392612  582673730      1377  2021-10-25 13:20:59  7.298842  80.734025
# 392613  582673731      1377  2021-10-25 13:21:14  7.298725  80.733523
# 392614  582673732      1377  2021-10-25 13:21:29  7.298230  80.733130
# 392615  582673733      1377  2021-10-25 13:21:44  7.297807  80.732997
# 392616  582673734      1377  2021-10-25 13:21:59  7.297535  80.732432
# ...           ...       ...                  ...       ...        ...
# 396733  585350956      1377  2021-10-27 19:02:53  7.290715  80.638227
# 396734  585350957      1377  2021-10-27 19:03:08  7.291095  80.637743
# 396735  585351802      1377  2021-10-27 19:03:23  7.291273  80.637273
# 396736  585351803      1377  2021-10-27 19:03:38  7.291202  80.636218
# 396737  585351804      1377  2021-10-27 19:03:53  7.291602  80.635130
#
#            speed        date      time  trip_id  segment_id
# 392612   7.55940  2021-10-25  13:20:59   1707.0     26993.0
# 392613   9.17927  2021-10-25  13:21:14   1707.0     26993.0
# 392614   5.93953  2021-10-25  13:21:29   1707.0     26993.0
# 392615   6.47948  2021-10-25  13:21:44   1707.0     26993.0
# 392616   9.71923  2021-10-25  13:21:59   1707.0     26993.0
# ...          ...         ...       ...      ...         ...
# 396733   5.39957  2021-10-27  19:02:53   1725.0     27296.0
# 396734   8.09935  2021-10-27  19:03:08   1725.0     27296.0
# 396735   5.39957  2021-10-27  19:03:23   1725.0     27296.0
# 396736  18.89850  2021-10-27  19:03:38   1725.0     27296.0
# 396737  12.41900  2021-10-27  19:03:53   1725.0     27296.0
#
# [4126 rows x 10 columns]

# %%
result_df.to_csv("./gps_data_segmented_1000M.csv", index = False)

# %%
result_df[result_df['segment_id'] == 3665.0]
# Out:
#               id  deviceid           devicetime  latitude  longitude  \
# 51345  571476016       123  2021-10-12 15:02:30  7.299112  80.734622
# 51346  571478006       123  2021-10-12 15:05:31  7.295168  80.735662
# 51347  571478355       123  2021-10-12 15:05:54  7.295817  80.735328
# 51348  571478356       123  2021-10-12 15:05:55  7.295790  80.735305
# 51349  571479164       123  2021-10-12 15:06:10  7.295165  80.734663
# ...          ...       ...                  ...       ...        ...
# 51446  571636557       123  2021-10-12 17:33:41  7.282172  80.722955
# 51447  571636621       123  2021-10-12 17:33:45  7.282228  80.722912
# 51448  571636716       123  2021-10-12 17:33:50  7.282302  80.722858
# 51449  571639882       123  2021-10-12 17:34:05  7.283058  80.722237
# 51450  571639881       123  2021-10-12 17:34:20  7.283538  80.721820
#
#           speed        date      time  trip_id  segment_id
# 51345   5.39957  2021-10-12  15:02:30    230.0      3665.0
# 51346   0.00000  2021-10-12  15:05:31    230.0      3665.0
# 51347   3.23974  2021-10-12  15:05:54    230.0      3665.0
# 51348   5.39957  2021-10-12  15:05:55    230.0      3665.0
# 51349   7.55940  2021-10-12  15:06:10    230.0      3665.0
# ...         ...         ...       ...      ...         ...
# 51446   2.69978  2021-10-12  17:33:41    230.0      3665.0
# 51447   0.00000  2021-10-12  17:33:45    230.0      3665.0
# 51448   3.23974  2021-10-12  17:33:50    230.0      3665.0
# 51449  14.03890  2021-10-12  17:34:05    230.0      3665.0
# 51450   6.47948  2021-10-12  17:34:20    230.0      3665.0
#
# [106 rows x 10 columns]

# %%
groupby_res = result_df.groupby('segment_id').count()
groupby_res[groupby_res['id']>100]
# Out:
#              id  deviceid  devicetime  latitude  longitude  speed  date  time  \
# segment_id
# 3792.0      128       128         128       128        128    128   128   128
# 3795.0      333       333         333       333        333    333   333   333
# 3894.0      106       106         106       106        106    106   106   106
# 3897.0      273       273         273       273        273    273   273   273
# 3999.0      338       338         338       338        338    338   338   338
# ...         ...       ...         ...       ...        ...    ...   ...   ...
# 21723.0     108       108         108       108        108    108   108   108
# 23325.0     154       154         154       154        154    154   154   154
# 23328.0     119       119         119       119        119    119   119   119
# 24566.0     179       179         179       179        179    179   179   179
# 25143.0     224       224         224       224        224    224   224   224
#
#             trip_id
# segment_id
# 3792.0          128
# 3795.0          333
# 3894.0          106
# 3897.0          273
# 3999.0          338
# ...             ...
# 21723.0         108
# 23325.0         154
# 23328.0         119
# 24566.0         179
# 25143.0         224
#
# [67 rows x 9 columns]

# %%
result_df[result_df['segment_id'] == 23328.0]
# Out:
#                id  deviceid           devicetime  latitude  longitude  \
# 346754  560361273      1250  2021-10-01 08:05:37  7.290413  80.639330
# 346755  560361276      1250  2021-10-01 08:05:52  7.290585  80.638353
# 346756  560367996      1250  2021-10-01 08:06:07  7.291150  80.637575
# 346757  560367997      1250  2021-10-01 08:06:22  7.291328  80.636963
# 346758  560367998      1250  2021-10-01 08:06:37  7.291303  80.636090
# ...           ...       ...                  ...       ...        ...
# 346973  560437022      1358  2021-10-01 08:44:39  7.290845  80.638165
# 346974  560444210      1358  2021-10-01 08:44:54  7.291197  80.637432
# 346975  560444211      1358  2021-10-01 08:45:09  7.291322  80.636848
# 346976  560444212      1358  2021-10-01 08:45:24  7.291487  80.635713
# 346977  560444213      1358  2021-10-01 08:45:39  7.291728  80.635040
#
#            speed        date      time  trip_id  segment_id
# 346754  11.33910  2021-10-01  08:05:37   1498.0     25143.0
# 346755  16.73870  2021-10-01  08:05:52   1498.0     25143.0
# 346756   7.01944  2021-10-01  08:06:07   1498.0     25143.0
# 346757  13.49890  2021-10-01  08:06:22   1498.0     25143.0
# 346758  11.87910  2021-10-01  08:06:37   1498.0     25143.0
# ...          ...         ...       ...      ...         ...
# 346973  10.79910  2021-10-01  08:44:39   1498.0     25143.0
# 346974   8.63931  2021-10-01  08:44:54   1498.0     25143.0
# 346975  15.11880  2021-10-01  08:45:09   1498.0     25143.0
# 346976  17.27860  2021-10-01  08:45:24   1498.0     25143.0
# 346977   4.31966  2021-10-01  08:45:39   1498.0     25143.0
#
# [224 rows x 10 columns]

# %%
import folium
df = pd.read_csv("./segment_split_points.csv")
segment = result_df[(result_df['segment_id'] == 17) | (result_df['segment_id'] == 16)]

# Create a folium map centered around the mean of latitudes and longitudes
map_center = [df['latitude'].mean(), df['longitude'].mean()]
mymap = folium.Map(location=map_center, zoom_start=14)

# Add markers for each row in the DataFrame
for index, row in df.iterrows():
    folium.Marker(location=[row['latitude'], row['longitude']]).add_to(mymap)

# Add markers for each row in the DataFrame
for index, row in segment.iterrows():
    folium.Marker(location=[row['latitude'], row['longitude']], icon=folium.Icon(color="green")).add_to(mymap)

# Save the map as an HTML file
mymap.save("map.html")

# %%
result_df.to_csv("./segment_split_points.csv", index=False)

# %%
import datetime
parsed_date = "2023-12-05 10:00:00"
start_time = pd.Timestamp(parsed_date)

# Generate a range of 3-minute intervals for the current record
time_intervals = pd.date_range(start=start_time, periods=10, freq='3T')
print(time_intervals)
# Out:
# DatetimeIndex(['2023-12-05 10:00:00', '2023-12-05 10:03:00',
#                '2023-12-05 10:06:00', '2023-12-05 10:09:00',
#                '2023-12-05 10:12:00', '2023-12-05 10:15:00',
#                '2023-12-05 10:18:00', '2023-12-05 10:21:00',
#                '2023-12-05 10:24:00', '2023-12-05 10:27:00'],
#               dtype='datetime64[ns]', freq='3T')

# %%
for index, row in bus_trips_ts.iterrows():
      print(f"Processing trip-ID: {index+1}")
      # get the maximum and minimum indexes of trip's gps points
      max_index = np.max(np.where(gps_data_ts['trip_id'] == row['trip_id']))
      min_index = np.min(np.where(gps_data_ts['trip_id'] == row['trip_id']))

      # intialize lower pointer so I can use iloc with range
      lower_ptr = min_index

      # this is the pointer that points to splitting point
      split_points_ptr = 0

      prev_dist = None
      consec = 0
      # loop through entire trip's gps points
      for ind in range(min_index, max_index+1):

        if len(split_points_df) == split_points_ptr:
          gps_data_ts.loc[lower_ptr:max_index, "segment_id"] = segment_id
          segment_id +=1
          break
        gps_cordinate = (gps_data_ts.iloc[ind]['latitude'], gps_data_ts.iloc[ind]['longitude'])
        split_point_cordinate = (split_points_df.iloc[split_points_ptr]['latitude'], split_points_df.iloc[split_points_ptr]['longitude'])
        dist = geodesic(gps_cordinate, split_point_cordinate).meters

        if prev_dist and dist> prev_dist:
          consec+=1
          if consec>3:
            print("Something has missing")

        if dist<=100:
          gps_data_ts.loc[lower_ptr:ind, "segment_id"] = segment_id
          segment_id +=1
          lower_ptr = ind + 1
          split_points_ptr += 1

          # aditional consec thing
          prev_dist = None
          consec = 0

        prev_dist = dist
    return gps_data_ts
# Out:
#   File <tokenize>:42
#     return gps_data_ts
#     ^
# IndentationError: unindent does not match any outer indentation level
